# %% [markdown]
# ### This notebook uses the old ACS data dictionary provided during the DataDive event on Sep 18
# ### Please check the _'acs_dictionary_updated_eda'_ notebook for EDA on recently scraped ACS dictionaries (scraping code in _update_acs_dictionaries_)

# %% [markdown]
# <font color = Blue>
# Research Question 3 (ACS): What are the differences between the 2014 and 2019 5-year American Community Survey datasets? Which variables or labels are missing from the 2014 data but in the 2019 data, and vice versa? Which 2019 variables have changed significantly from the 2014 estimates?

# %%
# Import libraries
import os
import pandas as pd
import numpy as np
from functools import reduce

# %%
# Read the dictionary csv
acs_dic = pd.read_csv('data/acs5_variable_dict_2014_2019.csv')

# Change label field to upper case
acs_dic['label'] = acs_dic['label'].str.upper()

# Split the labels and store them in a list
acs_dic['label'] = acs_dic['label'].str.split('!!')

# %%
# Read other data files for parallel EDA
hill_acs_2014 = pd.read_csv("data/hillsborough_acs5-2014_census.csv")
miami_dade_acs_2014 = pd.read_csv("data/miami_dade_acs5-2014_census.csv")
orange_acs_2014 = pd.read_csv("data/orange_acs5-2014_census.csv")

hill_acs_2019 = pd.read_csv("data/hillsborough_acs5-2019_census.csv")
miami_dade_acs_2019 = pd.read_csv("data/miami_dade_acs5-2019_census.csv")
orange_acs_2019 = pd.read_csv("data/orange_acs5-2019_census.csv")

# %%
hill_acs_2014.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4726e4e0ce75> in <module>
# ----> 1 hill_acs_2014.head(5)
#
# NameError: name 'hill_acs_2014' is not defined

# %%
hill_acs_2019.head(5)
# Out:
#                                                  index  DP02_0001E  \
# 0    Census Tract 4.01, Hillsborough County, Florid...         926
# 1    Census Tract 101.05, Hillsborough County, Flor...        1496
# 2    Census Tract 102.03, Hillsborough County, Flor...         766
# 3    Census Tract 106, Hillsborough County, Florida...        1108
# 4    Census Tract 23, Hillsborough County, Florida:...        1419
# ..                                                 ...         ...
# 316  Census Tract 1.02, Hillsborough County, Florid...        2484
# 317  Census Tract 115.04, Hillsborough County, Flor...         797
# 318  Census Tract 141.06, Hillsborough County, Flor...        1311
# 319  Census Tract 128, Hillsborough County, Florida...        1500
# 320  Census Tract 101.08, Hillsborough County, Flor...         753
#
#      DP02_0001PE  DP02_0002E  DP02_0002PE  DP02_0003E  DP02_0003PE  \
# 0            926         294         31.7         124         13.4
# 1           1496         921         61.6         325         21.7
# 2            766         222         29.0          40          5.2
# 3           1108         598         54.0         244         22.0
# 4           1419         606         42.7         213         15.0
# ..           ...         ...          ...         ...          ...
# 316         2484         478         19.2         172          6.9
# 317          797         519         65.1         153         19.2
# 318         1311         602         45.9         239         18.2
# 319         1500         773         51.5         209         13.9
# 320          753         462         61.4         154         20.5
#
#      DP02_0004E  DP02_0004PE  DP02_0005E  ...  B25087_037E  B25087_038E  \
# 0            96         10.4          18  ...            0            0
# 1            78          5.2          52  ...            0            0
# 2            56          7.3          39  ...            0            0
# 3            48          4.3           9  ...            0            0
# 4           131          9.2          38  ...            0            0
# ..          ...          ...         ...  ...          ...          ...
# 316          70          2.8          56  ...            0            0
# 317          19          2.4           6  ...           25            0
# 318         150         11.4          86  ...            0            0
# 319          92          6.1          74  ...            0            0
# 320          43          5.7           7  ...            6            0
#
#      B25087_039E  B25088_001E  B25088_002E  B25088_003E  B25092_001E  \
# 0              0          991         1172          359         19.9
# 1             10          866         1549          391         17.3
# 2              0          608         1155          263         18.6
# 3             15         1241         1584          566         14.2
# 4             10         1174         1400          408         17.8
# ..           ...          ...          ...          ...          ...
# 316            0          779         1186          300         18.1
# 317           20         1534         2325          708         17.2
# 318            6          941         1352          352         17.3
# 319            0          850          987          337         14.9
# 320            0          948         1629          361         16.5
#
#      B25092_002E  B25092_003E        GEOID
# 0           26.3          9.0  12057000401
# 1           23.3          9.0  12057010105
# 2           21.9         15.7  12057010203
# 3           16.9          9.0  12057010600
# 4           18.7         14.2  12057002300
# ..           ...          ...          ...
# 316         26.8          9.0  12057000102
# 317         20.8          9.0  12057011504
# 318         21.3         11.9  12057014106
# 319         19.0          9.0  12057012800
# 320         27.6          9.0  12057010108
#
# [321 rows x 1613 columns]

# %%
# Create a df with a list of field names and datasets they're present in
df1 = pd.DataFrame(columns = ['variable_code'], data = hill_acs_2014.columns)
df1['dataset1'] = 'hill_14'
df2 = pd.DataFrame(columns = ['variable_code'], data = miami_dade_acs_2014.columns)
df2['dataset2'] = 'miami_dade_14'
df3 = pd.DataFrame(columns = ['variable_code'], data = orange_acs_2014.columns)
df3['dataset3'] = 'orange_14'
df4 = pd.DataFrame(columns = ['variable_code'], data = hill_acs_2019.columns)
df4['dataset4'] = 'hill_19'
df5 = pd.DataFrame(columns = ['variable_code'], data = miami_dade_acs_2019.columns)
df5['dataset5'] = 'miami_dade_19'
df6 = pd.DataFrame(columns = ['variable_code'], data = orange_acs_2019.columns)
df6['dataset6'] = 'orange_19'

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['variable_code'], how='outer'), 
                   [df1, df2, df3, df4, df5, df6])

df_merged['datasets'] = df_merged[['dataset1', 'dataset2', 'dataset3', 'dataset4', 'dataset5', 'dataset6',]]\
                        .apply(lambda x: ', '.join(x.dropna()), axis=1)
df_merged = df_merged[['variable_code', 'datasets']]
df_merged = df_merged.loc[df_merged['variable_code'] != 'index']

# %%
df_merged.head(5)
# Out:
#   variable_code                                           datasets
# 1    DP02_0001E  hill_14, miami_dade_14, orange_14, hill_19, mi...
# 2   DP02_0001PE  hill_14, miami_dade_14, orange_14, hill_19, mi...
# 3    DP02_0002E  hill_14, miami_dade_14, orange_14, hill_19, mi...
# 4   DP02_0002PE  hill_14, miami_dade_14, orange_14, hill_19, mi...
# 5    DP02_0003E  hill_14, miami_dade_14, orange_14, hill_19, mi...

# %%
# Separate 2014 variable codes from 2019 variable codes
acs_dic_14 = acs_dic.loc[acs_dic['acs_year'] == 2014]
acs_dic_19 = acs_dic.loc[acs_dic['acs_year'] == 2019]

# %%
print('Number of variable codes in 2014 dataset:', len(pd.unique(acs_dic_14['variable_code'])))
print('Number of variable codes in 2019 dataset:', len(pd.unique(acs_dic_19['variable_code'])))
# Out:
# Number of variable codes in 2014 dataset: 4088
# Number of variable codes in 2019 dataset: 4176

# %%
# Format the field names add dataset year as a suffix 
# (except for 'variable_code' field since it'll be used to join the 2 tables)
acs_dic_14.columns = ['{}{}'.format(c, '' if c == 'variable_code' else '_14') for c in acs_dic_14.columns]
acs_dic_19.columns = ['{}{}'.format(c, '' if c == 'variable_code' else '_19') for c in acs_dic_19.columns]

# %%
# Merge 2014 dataset, 2019 dataset and df_merged (field names from each file) on 'variable_code'
acs_dic_compare = reduce(lambda  left,right: pd.merge(left,right,on=['variable_code'], how='outer'), 
                   [acs_dic_14, acs_dic_19, df_merged])

# Compare 'concept', 'predicateType', 'predicateOnly' and 'label' fields in both of the datasets
acs_dic_compare['concept_match'] = np.where(acs_dic_compare['concept_14'] == acs_dic_compare['concept_19'], True, False)
acs_dic_compare['predicateType_match'] = np.where(acs_dic_compare['predicateType_14'] == acs_dic_compare['predicateType_19'], True, False)
acs_dic_compare['predicateOnly_match'] = np.where(acs_dic_compare['predicateOnly_14'] == acs_dic_compare['predicateOnly_19'], True, False)
acs_dic_compare['label_match'] = np.where(acs_dic_compare['label_14'] == acs_dic_compare['label_19'], True, False)

# %%
# Replace NaN values in 'label_14' and 'label_19' columns with an empty list
acs_dic_compare['label_14'] = acs_dic_compare['label_14'].apply(lambda d: d if isinstance(d, list) else [])
acs_dic_compare['label_19'] = acs_dic_compare['label_19'].apply(lambda d: d if isinstance(d, list) else [])
acs_dic_compare['datasets'].fillna('', inplace = True)
acs_dic_compare.head(5)
# Out:
#   variable_code                                           label_14  \
# 0   DP02_0019EA  [ANNOTATION OF ESTIMATE, RELATIONSHIP, POPULAT...
# 1    DP02_0126E     [ESTIMATE, ANCESTRY, TOTAL POPULATION, DANISH]
# 2   DP02_0072EA  [ANNOTATION OF ESTIMATE, DISABILITY STATUS OF ...
# 3  DP02_0069PMA  [ANNOTATION OF PERCENT MARGIN OF ERROR, VETERA...
# 4    DP02_0126M  [MARGIN OF ERROR, ANCESTRY, TOTAL POPULATION, ...
#
#                                           concept_14 predicateType_14  \
# 0  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...           string
# 1  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...              int
# 2  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...           string
# 3  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...           string
# 4  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...              int
#
#   group_14  limit_14 predicateOnly_14  acs_year_14  \
# 0     DP02       0.0             True       2014.0
# 1     DP02       0.0             True       2014.0
# 2     DP02       0.0             True       2014.0
# 3     DP02       0.0             True       2014.0
# 4     DP02       0.0             True       2014.0
#
#                                             label_19  \
# 0  [ANNOTATION OF ESTIMATE, RELATIONSHIP, POPULAT...
# 1      [ESTIMATE, ANCESTRY, TOTAL POPULATION, CZECH]
# 2  [ANNOTATION OF ESTIMATE, DISABILITY STATUS OF ...
# 3  [ANNOTATION OF PERCENT MARGIN OF ERROR, VETERA...
# 4  [MARGIN OF ERROR, ANCESTRY, TOTAL POPULATION, ...
#
#                                           concept_19  ... predicateOnly_19  \
# 0  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...  ...             True
# 1  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...  ...             True
# 2  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...  ...             True
# 3  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...  ...             True
# 4  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...  ...             True
#
#   acs_year_19                                           datasets  \
# 0      2019.0
# 1      2019.0  hill_14, miami_dade_14, orange_14, hill_19, mi...
# 2      2019.0
# 3      2019.0
# 4      2019.0
#
#   concept_match  predicateType_match predicateOnly_match  label_match  \
# 0          True                 True                True        False
# 1          True                 True                True        False
# 2          True                 True                True        False
# 3          True                 True                True        False
# 4          True                 True                True        False
#
#                                           label_same        label_14_diff  \
# 0  [RELATIONSHIP, ANNOTATION OF ESTIMATE, POPULAT...             [SPOUSE]
# 1             [ESTIMATE, ANCESTRY, TOTAL POPULATION]             [DANISH]
# 2  [DISABILITY STATUS OF THE CIVILIAN NONINSTITUT...     [UNDER 18 YEARS]
# 3  [VETERAN STATUS, CIVILIAN POPULATION 18 YEARS ...  [CIVILIAN VETERANS]
# 4      [ANCESTRY, TOTAL POPULATION, MARGIN OF ERROR]             [DANISH]
#
#                                        label_19_diff
# 0                                      [HOUSEHOLDER]
# 1                                            [CZECH]
# 2  [TOTAL CIVILIAN NONINSTITUTIONALIZED POPULATIO...
# 3                                                 []
# 4                                            [CZECH]
#
# [5 rows x 23 columns]

# %%
# Identify the difference between labels from 2014 and 2019 dataset

# Common labels for each row:
acs_dic_compare['label_same'] = acs_dic_compare.apply(lambda row: list(set(row['label_14']).intersection(set(row['label_19']))), axis = 1)

# Labels present in 2014's dataset but not in 2019's
acs_dic_compare['label_14_diff'] = acs_dic_compare.apply(lambda row: list(set(row['label_14']).difference(set(row['label_same']))), axis = 1)

# Labels present in 2019's datatset but not in 2014's
acs_dic_compare['label_19_diff'] = acs_dic_compare.apply(lambda row: list(set(row['label_19']).difference(set(row['label_same']))), axis = 1)

# %% [markdown]
# ## Data dictionary for the new fields:
# - *label_14, concept_14, predicateType_14, group_14, limit_14*: labels, concepts, predicateTypes, groups, limits for __2014's__ variable codes
#
# - *label_19, concept_19, predicateType_19, group_19, limit_19*: labels, concepts, predicateTypes, groups, limits for __2019's__ variable codes
#
# <font color = Blue>
#
# - *datasets*: variable code is present in these datafiles
#
# - *concept_match, predicateType_match, predicateOnly_match, label_match*:(T/F) if 2014's fields match with 2019's fields
#
# - *label_same*: common labels in 2014's and 2019's dataset
#
# - *label_14_diff*: labels present in 2014's dataset but NOT in 2019's
#
# - *label_19_diff*: labels present in 2019's dataset but NOT in 2014's

# %%
acs_dic_compare.head(5)
# Out:
#   variable_code                                           label_14  \
# 0   DP02_0019EA  [ANNOTATION OF ESTIMATE, RELATIONSHIP, POPULAT...
# 1    DP02_0126E     [ESTIMATE, ANCESTRY, TOTAL POPULATION, DANISH]
# 2   DP02_0072EA  [ANNOTATION OF ESTIMATE, DISABILITY STATUS OF ...
# 3  DP02_0069PMA  [ANNOTATION OF PERCENT MARGIN OF ERROR, VETERA...
# 4    DP02_0126M  [MARGIN OF ERROR, ANCESTRY, TOTAL POPULATION, ...
#
#                                           concept_14 predicateType_14  \
# 0  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...           string
# 1  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...              int
# 2  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...           string
# 3  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...           string
# 4  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...              int
#
#   group_14  limit_14 predicateOnly_14  acs_year_14  \
# 0     DP02       0.0             True       2014.0
# 1     DP02       0.0             True       2014.0
# 2     DP02       0.0             True       2014.0
# 3     DP02       0.0             True       2014.0
# 4     DP02       0.0             True       2014.0
#
#                                             label_19  \
# 0  [ANNOTATION OF ESTIMATE, RELATIONSHIP, POPULAT...
# 1      [ESTIMATE, ANCESTRY, TOTAL POPULATION, CZECH]
# 2  [ANNOTATION OF ESTIMATE, DISABILITY STATUS OF ...
# 3  [ANNOTATION OF PERCENT MARGIN OF ERROR, VETERA...
# 4  [MARGIN OF ERROR, ANCESTRY, TOTAL POPULATION, ...
#
#                                           concept_19 predicateType_19  \
# 0  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...           string
# 1  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...              int
# 2  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...           string
# 3  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...           string
# 4  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...              int
#
#   group_19  limit_19 predicateOnly_19  acs_year_19  \
# 0     DP02       0.0             True       2019.0
# 1     DP02       0.0             True       2019.0
# 2     DP02       0.0             True       2019.0
# 3     DP02       0.0             True       2019.0
# 4     DP02       0.0             True       2019.0
#
#                                             datasets  concept_match  \
# 0                                                NaN           True
# 1  hill_14, miami_dade_14, orange_14, hill_19, mi...           True
# 2                                                NaN           True
# 3                                                NaN           True
# 4                                                NaN           True
#
#    predicateType_match  predicateOnly_match  label_match
# 0                 True                 True        False
# 1                 True                 True        False
# 2                 True                 True        False
# 3                 True                 True        False
# 4                 True                 True        False

# %%
# Number of matches
for c in ['concept_match', 'predicateType_match', 'predicateOnly_match', 'label_match']:
    print('\n')
    print(acs_dic_compare[c].value_counts())
# Out:
# True     4088
# False     659
# Name: concept_match, dtype: int64
#
#
# True     3872
# False     875
# Name: predicateType_match, dtype: int64
#
#
# True     4088
# False     659
# Name: predicateOnly_match, dtype: int64
#
#
# False    4203
# True      544
# Name: label_match, dtype: int64

# %% [markdown]
# ## How many fields from data dictionary are not present in any of the files?

# %%
print('Number of fields from data dictinary that are not present in any of the files:', acs_dic_compare['datasets'].isna().sum())
acs_dic_compare.loc[acs_dic_compare['datasets'].isna()].head(5)
# Out:
# Number of fields from data dictinary that are not present in any of the files: 3132
#   variable_code                                           label_14  \
# 0   DP02_0019EA  [ANNOTATION OF ESTIMATE, RELATIONSHIP, POPULAT...
# 2   DP02_0072EA  [ANNOTATION OF ESTIMATE, DISABILITY STATUS OF ...
# 3  DP02_0069PMA  [ANNOTATION OF PERCENT MARGIN OF ERROR, VETERA...
# 4    DP02_0126M  [MARGIN OF ERROR, ANCESTRY, TOTAL POPULATION, ...
# 5  DP02_0057PMA  [ANNOTATION OF PERCENT MARGIN OF ERROR, SCHOOL...
#
#                                           concept_14 predicateType_14  \
# 0  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...           string
# 2  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...           string
# 3  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...           string
# 4  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...              int
# 5  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...           string
#
#   group_14  limit_14 predicateOnly_14  acs_year_14  \
# 0     DP02       0.0             True       2014.0
# 2     DP02       0.0             True       2014.0
# 3     DP02       0.0             True       2014.0
# 4     DP02       0.0             True       2014.0
# 5     DP02       0.0             True       2014.0
#
#                                             label_19  \
# 0  [ANNOTATION OF ESTIMATE, RELATIONSHIP, POPULAT...
# 2  [ANNOTATION OF ESTIMATE, DISABILITY STATUS OF ...
# 3  [ANNOTATION OF PERCENT MARGIN OF ERROR, VETERA...
# 4  [MARGIN OF ERROR, ANCESTRY, TOTAL POPULATION, ...
# 5  [ANNOTATION OF PERCENT MARGIN OF ERROR, SCHOOL...
#
#                                           concept_19 predicateType_19  \
# 0  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...           string
# 2  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...           string
# 3  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...           string
# 4  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...              int
# 5  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...           string
#
#   group_19  limit_19 predicateOnly_19  acs_year_19 datasets  concept_match  \
# 0     DP02       0.0             True       2019.0      NaN           True
# 2     DP02       0.0             True       2019.0      NaN           True
# 3     DP02       0.0             True       2019.0      NaN           True
# 4     DP02       0.0             True       2019.0      NaN           True
# 5     DP02       0.0             True       2019.0      NaN           True
#
#    predicateType_match  predicateOnly_match  label_match
# 0                 True                 True        False
# 2                 True                 True        False
# 3                 True                 True        False
# 4                 True                 True        False
# 5                 True                 True        False

# %% [markdown]
# ## How many fields from the files are not present in the data dictionary?

# %%
print('Number of fields from data dictinary that are not present in any of the files:', \
      len(acs_dic_compare.loc[(acs_dic_compare['concept_14'].isna()) & (acs_dic_compare['concept_19'].isna())].index))
acs_dic_compare.loc[(acs_dic_compare['concept_14'].isna()) & (acs_dic_compare['concept_19'].isna())].reset_index(drop = True)[['variable_code', 'datasets']].head(5)
# Out:
# Number of fields from data dictinary that are not present in any of the files: 571
#     variable_code                                           datasets
# 0  S1701_C01_001E  hill_14, miami_dade_14, orange_14, hill_19, mi...
# 1  S1701_C01_002E  hill_14, miami_dade_14, orange_14, hill_19, mi...
# 2  S1701_C01_003E  hill_14, miami_dade_14, orange_14, hill_19, mi...
# 3  S1701_C01_004E  hill_14, miami_dade_14, orange_14, hill_19, mi...
# 4  S1701_C01_005E  hill_14, miami_dade_14, orange_14, hill_19, mi...

# %%
#df8 = acs_dic_compare.loc[(acs_dic_compare['concept_14'].isna()) & (acs_dic_compare['concept_19'].isna())].reset_index(drop = True)[['variable_code', 'datasets']]
#df8.to_csv('acs_dictionary_missing_variable_codes.csv')

# %%
acs_dic_compare.to_csv('acs_dictinary_transformed.csv')

# %%
# Find number of variable codes associated with each label 
acs_dic_14['label_14'] = acs_dic_14.apply(lambda row: str(row['label_14']), axis = 1)
acs_dic_14_labels = acs_dic_14.groupby('label_14')['variable_code'].apply(list).reset_index()
# Out:
# <ipython-input-18-082515667985>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   acs_dic_14['label_14'] = acs_dic_14.apply(lambda row: str(row['label_14']), axis = 1)

# %%
# Are there labels with more than 1 variable codes?
acs_dic_14_labels['ct_variable_code'] = acs_dic_14_labels['variable_code'].apply(lambda x: len(x))
acs_dic_14_labels.loc[acs_dic_14_labels['ct_variable_code']>1]
# Out:
#                                                label_14  \
# 420   ['ANNOTATION OF ESTIMATE', 'SELECTED MONTHLY O...
# 425   ['ANNOTATION OF ESTIMATE', 'SEX AND AGE', '18 ...
# 438   ['ANNOTATION OF ESTIMATE', 'SEX AND AGE', '65 ...
# 928   ['ANNOTATION OF MARGIN OF ERROR', 'SELECTED MO...
# 933   ['ANNOTATION OF MARGIN OF ERROR', 'SEX AND AGE...
# 946   ['ANNOTATION OF MARGIN OF ERROR', 'SEX AND AGE...
# 1436  ['ANNOTATION OF PERCENT MARGIN OF ERROR', 'SEL...
# 1441  ['ANNOTATION OF PERCENT MARGIN OF ERROR', 'SEX...
# 1454  ['ANNOTATION OF PERCENT MARGIN OF ERROR', 'SEX...
# 1944  ['ANNOTATION OF PERCENT', 'SELECTED MONTHLY OW...
# 1949  ['ANNOTATION OF PERCENT', 'SEX AND AGE', '18 Y...
# 1962  ['ANNOTATION OF PERCENT', 'SEX AND AGE', '65 Y...
# 2452  ['ESTIMATE', 'SELECTED MONTHLY OWNER COSTS AS ...
# 2457   ['ESTIMATE', 'SEX AND AGE', '18 YEARS AND OVER']
# 2470   ['ESTIMATE', 'SEX AND AGE', '65 YEARS AND OVER']
# 2960  ['MARGIN OF ERROR', 'SELECTED MONTHLY OWNER CO...
# 2965  ['MARGIN OF ERROR', 'SEX AND AGE', '18 YEARS A...
# 2978  ['MARGIN OF ERROR', 'SEX AND AGE', '65 YEARS A...
# 3468  ['PERCENT MARGIN OF ERROR', 'SELECTED MONTHLY ...
# 3473  ['PERCENT MARGIN OF ERROR', 'SEX AND AGE', '18...
# 3486  ['PERCENT MARGIN OF ERROR', 'SEX AND AGE', '65...
# 3976  ['PERCENT', 'SELECTED MONTHLY OWNER COSTS AS A...
# 3981    ['PERCENT', 'SEX AND AGE', '18 YEARS AND OVER']
# 3994    ['PERCENT', 'SEX AND AGE', '65 YEARS AND OVER']
#
#                      variable_code  ct_variable_code
# 420     [DP04_0114EA, DP04_0123EA]                 2
# 425     [DP05_0022EA, DP05_0018EA]                 2
# 438     [DP05_0021EA, DP05_0025EA]                 2
# 928     [DP04_0123MA, DP04_0114MA]                 2
# 933     [DP05_0022MA, DP05_0018MA]                 2
# 946     [DP05_0021MA, DP05_0025MA]                 2
# 1436  [DP04_0123PMA, DP04_0114PMA]                 2
# 1441  [DP05_0018PMA, DP05_0022PMA]                 2
# 1454  [DP05_0021PMA, DP05_0025PMA]                 2
# 1944  [DP04_0114PEA, DP04_0123PEA]                 2
# 1949  [DP05_0018PEA, DP05_0022PEA]                 2
# 1962  [DP05_0025PEA, DP05_0021PEA]                 2
# 2452      [DP04_0114E, DP04_0123E]                 2
# 2457      [DP05_0022E, DP05_0018E]                 2
# 2470      [DP05_0025E, DP05_0021E]                 2
# 2960      [DP04_0114M, DP04_0123M]                 2
# 2965      [DP05_0022M, DP05_0018M]                 2
# 2978      [DP05_0025M, DP05_0021M]                 2
# 3468    [DP04_0123PM, DP04_0114PM]                 2
# 3473    [DP05_0022PM, DP05_0018PM]                 2
# 3486    [DP05_0021PM, DP05_0025PM]                 2
# 3976    [DP04_0123PE, DP04_0114PE]                 2
# 3981    [DP05_0022PE, DP05_0018PE]                 2
# 3994    [DP05_0021PE, DP05_0025PE]                 2

# %%
acs_dic_14[acs_dic_14['variable_code'].isin(['DP04_0114EA', 'DP04_0123EA'])]
# Out:
#      variable_code                                           label_14  \
# 2844   DP04_0114EA  ['ANNOTATION OF ESTIMATE', 'SELECTED MONTHLY O...
# 3433   DP04_0123EA  ['ANNOTATION OF ESTIMATE', 'SELECTED MONTHLY O...
#
#                             concept_14 predicateType_14 group_14  limit_14  \
# 2844  SELECTED HOUSING CHARACTERISTICS           string     DP04         0
# 3433  SELECTED HOUSING CHARACTERISTICS           string     DP04         0
#
#       predicateOnly_14  acs_year_14
# 2844              True         2014
# 3433              True         2014

# %% [markdown]
# ## QC in the breakout

# %%
acs_dic_compare.loc[acs_dic_compare['variable_code'] == 'DP04_0037E']
# Out:
#      variable_code                                   label_14  \
# 2456    DP04_0037E  [ESTIMATE, BEDROOMS, TOTAL HOUSING UNITS]
#
#                             concept_14 predicateType_14 group_14  limit_14  \
# 2456  SELECTED HOUSING CHARACTERISTICS              int     DP04       0.0
#
#      predicateOnly_14  acs_year_14  \
# 2456             True       2014.0
#
#                                                label_19  \
# 2456  [ESTIMATE, ROOMS, TOTAL HOUSING UNITS, MEDIAN ...
#
#                             concept_19  ... predicateOnly_19 acs_year_19  \
# 2456  SELECTED HOUSING CHARACTERISTICS  ...             True      2019.0
#
#                                                datasets concept_match  \
# 2456  hill_14, miami_dade_14, orange_14, hill_19, mi...          True
#
#       predicateType_match predicateOnly_match  label_match  \
# 2456                False                True        False
#
#                            label_same  label_14_diff          label_19_diff
# 2456  [ESTIMATE, TOTAL HOUSING UNITS]     [BEDROOMS]  [MEDIAN ROOMS, ROOMS]
#
# [1 rows x 23 columns]

# %%
acs_dic_compare.loc[acs_dic_compare['datasets'].apply(lambda x: ('miami_dade_19' in x) & ('miami_dade_14' not in x))]
# Out:
#      variable_code label_14 concept_14 predicateType_14 group_14  limit_14  \
# 4092   DP02_0153PE       []        NaN              NaN      NaN       NaN
# 4095    DP02_0153E       []        NaN              NaN      NaN       NaN
# 4101   DP04_0142PE       []        NaN              NaN      NaN       NaN
# 4105   DP04_0143PE       []        NaN              NaN      NaN       NaN
# 4109    DP04_0143E       []        NaN              NaN      NaN       NaN
# ...            ...      ...        ...              ...      ...       ...
# 4742   B25087_035E       []        NaN              NaN      NaN       NaN
# 4743   B25087_036E       []        NaN              NaN      NaN       NaN
# 4744   B25087_037E       []        NaN              NaN      NaN       NaN
# 4745   B25087_038E       []        NaN              NaN      NaN       NaN
# 4746   B25087_039E       []        NaN              NaN      NaN       NaN
#
#      predicateOnly_14  acs_year_14  \
# 4092              NaN          NaN
# 4095              NaN          NaN
# 4101              NaN          NaN
# 4105              NaN          NaN
# 4109              NaN          NaN
# ...               ...          ...
# 4742              NaN          NaN
# 4743              NaN          NaN
# 4744              NaN          NaN
# 4745              NaN          NaN
# 4746              NaN          NaN
#
#                                                label_19  \
# 4092  [PERCENT, COMPUTERS AND INTERNET USE, TOTAL HO...
# 4095  [ESTIMATE, COMPUTERS AND INTERNET USE, TOTAL H...
# 4101  [PERCENT, GROSS RENT AS A PERCENTAGE OF HOUSEH...
# 4105  [PERCENT, GROSS RENT AS A PERCENTAGE OF HOUSEH...
# 4109  [ESTIMATE, GROSS RENT AS A PERCENTAGE OF HOUSE...
# ...                                                 ...
# 4742                                                 []
# 4743                                                 []
# 4744                                                 []
# 4745                                                 []
# 4746                                                 []
#
#                                              concept_19  ... predicateOnly_19  \
# 4092  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...  ...             True
# 4095  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...  ...             True
# 4101                   SELECTED HOUSING CHARACTERISTICS  ...             True
# 4105                   SELECTED HOUSING CHARACTERISTICS  ...             True
# 4109                   SELECTED HOUSING CHARACTERISTICS  ...             True
# ...                                                 ...  ...              ...
# 4742                                                NaN  ...              NaN
# 4743                                                NaN  ...              NaN
# 4744                                                NaN  ...              NaN
# 4745                                                NaN  ...              NaN
# 4746                                                NaN  ...              NaN
#
#      acs_year_19                           datasets concept_match  \
# 4092      2019.0  hill_19, miami_dade_19, orange_19         False
# 4095      2019.0  hill_19, miami_dade_19, orange_19         False
# 4101      2019.0  hill_19, miami_dade_19, orange_19         False
# 4105      2019.0  hill_19, miami_dade_19, orange_19         False
# 4109      2019.0  hill_19, miami_dade_19, orange_19         False
# ...          ...                                ...           ...
# 4742         NaN  hill_19, miami_dade_19, orange_19         False
# 4743         NaN  hill_19, miami_dade_19, orange_19         False
# 4744         NaN  hill_19, miami_dade_19, orange_19         False
# 4745         NaN  hill_19, miami_dade_19, orange_19         False
# 4746         NaN  hill_19, miami_dade_19, orange_19         False
#
#       predicateType_match predicateOnly_match  label_match  label_same  \
# 4092                False               False        False          []
# 4095                False               False        False          []
# 4101                False               False        False          []
# 4105                False               False        False          []
# 4109                False               False        False          []
# ...                   ...                 ...          ...         ...
# 4742                False               False        False          []
# 4743                False               False        False          []
# 4744                False               False        False          []
# 4745                False               False        False          []
# 4746                False               False        False          []
#
#       label_14_diff                                      label_19_diff
# 4092             []  [COMPUTERS AND INTERNET USE, TOTAL HOUSEHOLDS,...
# 4095             []  [COMPUTERS AND INTERNET USE, TOTAL HOUSEHOLDS,...
# 4101             []  [OCCUPIED UNITS PAYING RENT (EXCLUDING UNITS W...
# 4105             []  [OCCUPIED UNITS PAYING RENT (EXCLUDING UNITS W...
# 4109             []  [OCCUPIED UNITS PAYING RENT (EXCLUDING UNITS W...
# ...             ...                                                ...
# 4742             []                                                 []
# 4743             []                                                 []
# 4744             []                                                 []
# 4745             []                                                 []
# 4746             []                                                 []
#
# [61 rows x 23 columns]

# %%
acs_dic_compare.loc[acs_dic_compare['datasets'].apply(lambda x: ('miami_dade_14' in x) & ('miami_dade_19' not in x))]
# Out:
#        variable_code label_14 concept_14 predicateType_14 group_14  limit_14  \
# 4479  S2506_C01_066E       []        NaN              NaN      NaN       NaN
# 4480  S2506_C01_067E       []        NaN              NaN      NaN       NaN
# 4481  S2506_C01_068E       []        NaN              NaN      NaN       NaN
#
#      predicateOnly_14  acs_year_14 label_19 concept_19  ... predicateOnly_19  \
# 4479              NaN          NaN       []        NaN  ...              NaN
# 4480              NaN          NaN       []        NaN  ...              NaN
# 4481              NaN          NaN       []        NaN  ...              NaN
#
#      acs_year_19                           datasets concept_match  \
# 4479         NaN  hill_14, miami_dade_14, orange_14         False
# 4480         NaN  hill_14, miami_dade_14, orange_14         False
# 4481         NaN  hill_14, miami_dade_14, orange_14         False
#
#       predicateType_match predicateOnly_match  label_match  label_same  \
# 4479                False               False        False          []
# 4480                False               False        False          []
# 4481                False               False        False          []
#
#       label_14_diff  label_19_diff
# 4479             []             []
# 4480             []             []
# 4481             []             []
#
# [3 rows x 23 columns]

# %% [markdown]
# ## Work with Dulakshi on Task 1

# %%
acs_dic_compare[(acs_dic_compare['label_14'].apply(lambda x: len(x)) != 0)]['label_match'].value_counts()
# Out:
# False    3544
# True      544
# Name: label_match, dtype: int64

# %%
q1 = acs_dic_compare[(acs_dic_compare['label_14'].apply(lambda x: len(x)) != 0)]

# %%
q1.loc[q1['datasets']!='']
# Out:
#      variable_code                                           label_14  \
# 1       DP02_0126E     [ESTIMATE, ANCESTRY, TOTAL POPULATION, DANISH]
# 10      DP02_0125E      [ESTIMATE, ANCESTRY, TOTAL POPULATION, CZECH]
# 11     DP02_0054PE  [PERCENT, SCHOOL ENROLLMENT, POPULATION 3 YEAR...
# 14      DP02_0124E       [ESTIMATE, ANCESTRY, TOTAL POPULATION, ARAB]
# 21      DP02_0123E   [ESTIMATE, ANCESTRY, TOTAL POPULATION, AMERICAN]
# ...            ...                                                ...
# 4067   DP05_0010PE             [PERCENT, SEX AND AGE, 35 TO 44 YEARS]
# 4074    DP05_0050E  [ESTIMATE, RACE, ONE RACE, NATIVE HAWAIIAN AND...
# 4076    DP05_0051E  [ESTIMATE, RACE, ONE RACE, NATIVE HAWAIIAN AND...
# 4080   DP05_0054PE  [PERCENT, RACE, TWO OR MORE RACES, WHITE AND B...
# 4084   DP05_0041PE          [PERCENT, RACE, ONE RACE, ASIAN, CHINESE]
#
#                                              concept_14 predicateType_14  \
# 1     SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...              int
# 10    SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...              int
# 11    SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...            float
# 14    SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...              int
# 21    SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...              int
# ...                                                 ...              ...
# 4067              ACS DEMOGRAPHIC AND HOUSING ESTIMATES            float
# 4074              ACS DEMOGRAPHIC AND HOUSING ESTIMATES              int
# 4076              ACS DEMOGRAPHIC AND HOUSING ESTIMATES              int
# 4080              ACS DEMOGRAPHIC AND HOUSING ESTIMATES            float
# 4084              ACS DEMOGRAPHIC AND HOUSING ESTIMATES            float
#
#      group_14  limit_14 predicateOnly_14  acs_year_14  \
# 1        DP02       0.0             True       2014.0
# 10       DP02       0.0             True       2014.0
# 11       DP02       0.0             True       2014.0
# 14       DP02       0.0             True       2014.0
# 21       DP02       0.0             True       2014.0
# ...       ...       ...              ...          ...
# 4067     DP05       0.0             True       2014.0
# 4074     DP05       0.0             True       2014.0
# 4076     DP05       0.0             True       2014.0
# 4080     DP05       0.0             True       2014.0
# 4084     DP05       0.0             True       2014.0
#
#                                                label_19  \
# 1         [ESTIMATE, ANCESTRY, TOTAL POPULATION, CZECH]
# 10         [ESTIMATE, ANCESTRY, TOTAL POPULATION, ARAB]
# 11    [PERCENT, SCHOOL ENROLLMENT, POPULATION 3 YEAR...
# 14     [ESTIMATE, ANCESTRY, TOTAL POPULATION, AMERICAN]
# 21               [ESTIMATE, ANCESTRY, TOTAL POPULATION]
# ...                                                 ...
# 4067  [PERCENT, SEX AND AGE, TOTAL POPULATION, 25 TO...
# 4074  [ESTIMATE, RACE, TOTAL POPULATION, ONE RACE, A...
# 4076  [ESTIMATE, RACE, TOTAL POPULATION, ONE RACE, A...
# 4080  [PERCENT, RACE, TOTAL POPULATION, ONE RACE, NA...
# 4084  [PERCENT, RACE, TOTAL POPULATION, ONE RACE, AM...
#
#                                              concept_19  ... predicateOnly_19  \
# 1     SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...  ...             True
# 10    SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...  ...             True
# 11    SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...  ...             True
# 14    SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...  ...             True
# 21    SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...  ...             True
# ...                                                 ...  ...              ...
# 4067              ACS DEMOGRAPHIC AND HOUSING ESTIMATES  ...             True
# 4074              ACS DEMOGRAPHIC AND HOUSING ESTIMATES  ...             True
# 4076              ACS DEMOGRAPHIC AND HOUSING ESTIMATES  ...             True
# 4080              ACS DEMOGRAPHIC AND HOUSING ESTIMATES  ...             True
# 4084              ACS DEMOGRAPHIC AND HOUSING ESTIMATES  ...             True
#
#      acs_year_19                                           datasets  \
# 1         2019.0  hill_14, miami_dade_14, orange_14, hill_19, mi...
# 10        2019.0  hill_14, miami_dade_14, orange_14, hill_19, mi...
# 11        2019.0  hill_14, miami_dade_14, orange_14, hill_19, mi...
# 14        2019.0  hill_14, miami_dade_14, orange_14, hill_19, mi...
# 21        2019.0  hill_14, miami_dade_14, orange_14, hill_19, mi...
# ...          ...                                                ...
# 4067      2019.0  hill_14, miami_dade_14, orange_14, hill_19, mi...
# 4074      2019.0  hill_14, miami_dade_14, orange_14, hill_19, mi...
# 4076      2019.0  hill_14, miami_dade_14, orange_14, hill_19, mi...
# 4080      2019.0  hill_14, miami_dade_14, orange_14, hill_19, mi...
# 4084      2019.0  hill_14, miami_dade_14, orange_14, hill_19, mi...
#
#      concept_match  predicateType_match predicateOnly_match  label_match  \
# 1             True                 True                True        False
# 10            True                 True                True        False
# 11            True                 True                True        False
# 14            True                 True                True        False
# 21            True                 True                True        False
# ...            ...                  ...                 ...          ...
# 4067          True                 True                True        False
# 4074          True                 True                True        False
# 4076          True                 True                True        False
# 4080          True                 True                True        False
# 4084          True                 True                True        False
#
#                                              label_same  \
# 1                [ESTIMATE, ANCESTRY, TOTAL POPULATION]
# 10               [ESTIMATE, ANCESTRY, TOTAL POPULATION]
# 11    [SCHOOL ENROLLMENT, PERCENT, POPULATION 3 YEAR...
# 14               [ESTIMATE, ANCESTRY, TOTAL POPULATION]
# 21               [ESTIMATE, ANCESTRY, TOTAL POPULATION]
# ...                                                 ...
# 4067                             [SEX AND AGE, PERCENT]
# 4074                         [ESTIMATE, RACE, ONE RACE]
# 4076                         [ESTIMATE, RACE, ONE RACE]
# 4080                                    [RACE, PERCENT]
# 4084                          [RACE, PERCENT, ONE RACE]
#
#                                           label_14_diff  \
# 1                                              [DANISH]
# 10                                              [CZECH]
# 11                                       [KINDERGARTEN]
# 14                                               [ARAB]
# 21                                           [AMERICAN]
# ...                                                 ...
# 4067                                   [35 TO 44 YEARS]
# 4074  [NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER, S...
# 4076  [OTHER PACIFIC ISLANDER, NATIVE HAWAIIAN AND O...
# 4080  [TWO OR MORE RACES, WHITE AND BLACK OR AFRICAN...
# 4084                                   [ASIAN, CHINESE]
#
#                                           label_19_diff
# 1                                               [CZECH]
# 10                                               [ARAB]
# 11                          [NURSERY SCHOOL, PRESCHOOL]
# 14                                           [AMERICAN]
# 21                                                   []
# ...                                                 ...
# 4067                 [25 TO 34 YEARS, TOTAL POPULATION]
# 4074              [ASIAN, TOTAL POPULATION, VIETNAMESE]
# 4076             [ASIAN, OTHER ASIAN, TOTAL POPULATION]
# 4080  [ONE RACE, NATIVE HAWAIIAN AND OTHER PACIFIC I...
# 4084  [CHIPPEWA TRIBAL GROUPING, AMERICAN INDIAN AND...
#
# [1022 rows x 23 columns]

# %%
q1[['variable_code', 'label_14', 'label_19', 'label_same', 'label_14_diff', 'label_19_diff']].to_csv('label_mismatch_just_labels.csv')
