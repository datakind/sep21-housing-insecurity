# %% [markdown]
# # Research Question 3 (ACS)

# %% [markdown]
# What are the differences between the 2014 and 2019 5-year American Community Survey datasets? Which variables or labels are missing from the 2014 data but in the 2019 data, and vice versa? Which 2019 variables have changed significantly from the 2014 estimates?

# %% [markdown]
# ## Task 1

# %% [markdown]
# Using the ACS data dictionary found [here](https://drive.google.com/file/d/1Nd1TgI7-IARuoqDiexzT8MWLR6A3RQhx/view), compare variables from 2014 with variables from 2019. Do the variable codes and labels remain consistent across ACS versions? For example, does DP_002E in 2014 and DP_002E in 2019 refer to the same information? (Note that you can attempt this task using any county's ACS datasets - we know for certain that (e.g.) 2014 Hillsborough County and 2014 Miami-Dade County variables are consistent with each other.)

# %%
import pandas as pd

# %%
acs_data_dictionary_path = '../data/acs5_variable_dict_2014_2019.csv'
acs_data_dictionary_df = pd.read_csv(acs_data_dictionary_path)
acs_data_dictionary_df.head()
# Out:
#   variable_code                                              label  \
# 0   DP02_0019EA  Annotation of Estimate!!RELATIONSHIP!!Populati...
# 1    DP02_0126E       Estimate!!ANCESTRY!!Total population!!Danish
# 2   DP02_0072EA  Annotation of Estimate!!DISABILITY STATUS OF T...
# 3  DP02_0069PMA  Annotation of Percent Margin of Error!!VETERAN...
# 4    DP02_0126M  Margin of Error!!ANCESTRY!!Total population!!D...
#
#                                              concept predicateType group  \
# 0  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...        string  DP02
# 1  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...           int  DP02
# 2  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...        string  DP02
# 3  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...        string  DP02
# 4  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...           int  DP02
#
#    limit  predicateOnly  acs_year
# 0      0           True      2014
# 1      0           True      2014
# 2      0           True      2014
# 3      0           True      2014
# 4      0           True      2014

# %%
acs_2014 = acs_data_dictionary_df.loc[acs_data_dictionary_df['acs_year'] == 2014]
acs_2014.head()
# Out:
#   variable_code                                              label  \
# 0   DP02_0019EA  Annotation of Estimate!!RELATIONSHIP!!Populati...
# 1    DP02_0126E       Estimate!!ANCESTRY!!Total population!!Danish
# 2   DP02_0072EA  Annotation of Estimate!!DISABILITY STATUS OF T...
# 3  DP02_0069PMA  Annotation of Percent Margin of Error!!VETERAN...
# 4    DP02_0126M  Margin of Error!!ANCESTRY!!Total population!!D...
#
#                                              concept predicateType group  \
# 0  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...        string  DP02
# 1  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...           int  DP02
# 2  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...        string  DP02
# 3  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...        string  DP02
# 4  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...           int  DP02
#
#    limit  predicateOnly  acs_year
# 0      0           True      2014
# 1      0           True      2014
# 2      0           True      2014
# 3      0           True      2014
# 4      0           True      2014

# %%
acs_2019 = acs_data_dictionary_df.loc[acs_data_dictionary_df['acs_year'] == 2019]
acs_2019.head()
# Out:
#      variable_code                                              label  \
# 4088   DP02_0019EA  Annotation of Estimate!!RELATIONSHIP!!Populati...
# 4089    DP02_0126E        Estimate!!ANCESTRY!!Total population!!Czech
# 4090   DP02_0072EA  Annotation of Estimate!!DISABILITY STATUS OF T...
# 4091  DP02_0069PMA  Annotation of Percent Margin of Error!!VETERAN...
# 4092    DP02_0126M  Margin of Error!!ANCESTRY!!Total population!!C...
#
#                                                 concept predicateType group  \
# 4088  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...        string  DP02
# 4089  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...           int  DP02
# 4090  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...        string  DP02
# 4091  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...        string  DP02
# 4092  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...           int  DP02
#
#       limit  predicateOnly  acs_year
# 4088      0           True      2019
# 4089      0           True      2019
# 4090      0           True      2019
# 4091      0           True      2019
# 4092      0           True      2019

# %%
sheet_path = "../data/acs5_variable_dict_2014_2019.csv"
df = pd.read_csv(sheet_path, header=0)
df.head()
# Out:
#   variable_code                                              label  \
# 0   DP02_0019EA  Annotation of Estimate!!RELATIONSHIP!!Populati...
# 1    DP02_0126E       Estimate!!ANCESTRY!!Total population!!Danish
# 2   DP02_0072EA  Annotation of Estimate!!DISABILITY STATUS OF T...
# 3  DP02_0069PMA  Annotation of Percent Margin of Error!!VETERAN...
# 4    DP02_0126M  Margin of Error!!ANCESTRY!!Total population!!D...
#
#                                              concept predicateType group  \
# 0  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...        string  DP02
# 1  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...           int  DP02
# 2  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...        string  DP02
# 3  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...        string  DP02
# 4  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...           int  DP02
#
#    limit  predicateOnly  acs_year
# 0      0           True      2014
# 1      0           True      2014
# 2      0           True      2014
# 3      0           True      2014
# 4      0           True      2014

# %%
hillsborough_2014_df = pd.read_csv('../data/hillsborough_acs5-2014_census.csv')
hillsborough_2014_df.head()
# Out:
#                                                index  DP02_0001E  DP02_0001PE  \
# 0  Census Tract 111.03, Hillsborough County, Flor...        1268         1268
# 1  Census Tract 114.08, Hillsborough County, Flor...        1078         1078
# 2  Census Tract 114.13, Hillsborough County, Flor...        2111         2111
# 3  Census Tract 116.08, Hillsborough County, Flor...         428          428
# 4  Census Tract 116.11, Hillsborough County, Flor...        1596         1596
#
#    DP02_0002E  DP02_0002PE  DP02_0003E  DP02_0003PE  DP02_0004E  DP02_0004PE  \
# 0        1012         79.8         374         29.5         826         65.1
# 1         811         75.2         332         30.8         692         64.2
# 2        1444         68.4         704         33.3        1012         47.9
# 3         319         74.5         146         34.1         272         63.6
# 4         990         62.0         438         27.4         609         38.2
#
#    DP02_0005E  ...  B25087_027E  B25087_028E  B25087_029E  B25088_001E  \
# 0         302  ...           86            9          161         1452
# 1         288  ...           37            8           77         1512
# 2         465  ...           37           12           71         1476
# 3         110  ...            4           10           46         1603
# 4         241  ...           37           46           17         1032
#
#    B25088_002E  B25088_003E  B25092_001E  B25092_002E  B25092_003E  \
# 0         1944          555         17.9         22.3         11.5
# 1         1666          656         22.4         23.6         13.1
# 2         1776          455         23.3         26.6         14.8
# 3         1866          711         21.2         21.5         19.2
# 4         1187          437         22.7         24.3         16.8
#
#          GEOID
# 0  12057011103
# 1  12057011408
# 2  12057011413
# 3  12057011608
# 4  12057011611
#
# [5 rows x 1555 columns]

# %% [markdown]
# We know that the labels and codes for 2014 Hillsborough County and 2014 Miami-Dade County variables are consistent with each other.  Check this to make sure our code so far is correct.

# %%
miami_dade_county_2014_df = pd.read_csv('../data/miami_dade_acs5-2014_census.csv')
miami_dade_county_2014_df.head()
# Out:
#                                                index  DP02_0001E  DP02_0001PE  \
# 0  Census Tract 1.07, Miami-Dade County, Florida:...        1255         1255
# 1  Census Tract 1.18, Miami-Dade County, Florida:...         506          506
# 2  Census Tract 1.19, Miami-Dade County, Florida:...        2206         2206
# 3  Census Tract 1.21, Miami-Dade County, Florida:...         780          780
# 4  Census Tract 1.20, Miami-Dade County, Florida:...        1855         1855
#
#    DP02_0002E  DP02_0002PE  DP02_0003E  DP02_0003PE  DP02_0004E  DP02_0004PE  \
# 0         611         48.7         171         13.6         468         37.3
# 1         332         65.6          90         17.8         229         45.3
# 2        1192         54.0         498         22.6         894         40.5
# 3         487         62.4         100         12.8         401         51.4
# 4         998         53.8         475         25.6         789         42.5
#
#    DP02_0005E  ...  B25087_027E  B25087_028E  B25087_029E  B25088_001E  \
# 0         142  ...            0            0          284         1624
# 1          27  ...            0           11          219         2185
# 2         249  ...           45           73          552         1146
# 3          70  ...            0            0          421         1906
# 4         403  ...           40           41          280         1696
#
#    B25088_002E  B25088_003E  B25092_001E  B25092_002E  B25092_003E  \
# 0         2547         1001         24.2         24.5         22.3
# 1         3388         1001         46.5         50.0         26.3
# 2         1672          828         26.3         38.7         16.0
# 3         4001         1001         36.0         25.8         41.5
# 4         1953         1001         28.2         33.8         13.1
#
#          GEOID
# 0  12086000107
# 1  12086000118
# 2  12086000119
# 3  12086000121
# 4  12086000120
#
# [5 rows x 1555 columns]

# %%
hillsborough_2014_columns = set(hillsborough_2014_df.columns)
hillsborough_2014_columns.discard('index')

miami_dade_county_2014_columns = set(miami_dade_county_2014_df.columns)
miami_dade_county_2014_columns.discard('index')

hillsborough_2014_columns == miami_dade_county_2014_columns
# Out:
# True

# %% [markdown]
# They are indeed equal as expected.  Now let's test equality between each of the counties.

# %%
county_file_names = ['hillsborough_acs5-2014_census', 'miami_dade_acs5-2014_census', 
                     'hillsborough_acs5-2019_census', 'miami_dade_acs5-2019_census', 
                     'orange_acs5-2019_census', 'orange_acs5-2019_census']

def load_county_file_columns(county_file_name):
    full_file_name = '../data/{}.csv'.format(county_file_name)
    county_df = pd.read_csv(full_file_name)
    county_columns = set(county_df.columns)
    county_columns.discard('index')
    
    return county_columns

not_equal_list = []
for i in range(len(county_file_names)):
    county1 = county_file_names[i]
    for j in range(i + 1, len(county_file_names)):
        county2 = county_file_names[j]
        county1_columns = load_county_file_columns(county1)
        county2_columns = load_county_file_columns(county2)
        if county1_columns != county2_columns:
            not_equal_list.append((county1, county2))

print("Inconsistent county pairs:")            
for county1, county2 in not_equal_list:
    print('\t{} \t{}'.format(county1, county2))
# Out:
# Inconsistent county pairs:
# 	hillsborough_acs5-2014_census 	hillsborough_acs5-2019_census
# 	hillsborough_acs5-2014_census 	miami_dade_acs5-2019_census
# 	hillsborough_acs5-2014_census 	orange_acs5-2019_census
# 	hillsborough_acs5-2014_census 	orange_acs5-2019_census
# 	miami_dade_acs5-2014_census 	hillsborough_acs5-2019_census
# 	miami_dade_acs5-2014_census 	miami_dade_acs5-2019_census
# 	miami_dade_acs5-2014_census 	orange_acs5-2019_census
# 	miami_dade_acs5-2014_census 	orange_acs5-2019_census

# %% [markdown]
# ## Tasks 2 and 3
#
# Using the ACS data dictionary, compare the total number of variables reported in the 2014 5-year ACS to the 2019 5-year ACS. Are there any variables new to the 2019 survey that were not included in the 2014 survey?
#
# Using the ACS data dictionary, compare the total number of variables reported in the 2014 5-year ACS to the 2019 5-year ACS. Are there any variables missing from the 2019 survey that were included in the 2014 survey?

# %%
acs_2014_variable_codes = set(acs_2014.variable_code.unique())
acs_2019_variable_codes = set(acs_2019.variable_code.unique())
acs_2014_variable_codes == acs_2019_variable_codes
# Out:
# False

# %% [markdown]
# No, the variable codes are different across years.  Let's look at the codes that are in one year but not the other.

# %%
all_variable_codes = acs_2014_variable_codes.union(acs_2019_variable_codes)
all_variable_codes_list = list(all_variable_codes)
n = len(all_variable_codes_list)
print('variable_code\tIn 2014\tIn 2019')
for i in range(n):
    variable_code = all_variable_codes_list[i]
    in_2014 = variable_code in acs_2014_variable_codes
    in_2019 = variable_code in acs_2019_variable_codes
    if in_2014 and in_2019:
        continue
    print('{}\t{}\t{}'.format(variable_code, in_2014, in_2019))
# Out:
# variable_code	In 2014	In 2019
# DP05_0086M	False	True
# DP04_0143EA	False	True
# DP05_0087PEA	False	True
# DP05_0083EA	False	True
# DP05_0087M	False	True
# DP05_0085EA	False	True
# DP02_0153EA	False	True
# DP05_0085M	False	True
# DP02_0153MA	False	True
# DP05_0082M	False	True
# DP05_0088E	False	True
# DP04_0143PMA	False	True
# DP05_0083PM	False	True
# DP05_0089PE	False	True
# DP04_0142PEA	False	True
# DP05_0083M	False	True
# DP05_0082MA	False	True
# DP05_0083PMA	False	True
# DP02_0153PMA	False	True
# DP05_0084EA	False	True
# DP04_0142PM	False	True
# DP04_0142M	False	True
# DP05_0084PE	False	True
# DP05_0085PMA	False	True
# DP05_0086MA	False	True
# DP05_0089MA	False	True
# DP05_0088PEA	False	True
# DP05_0084MA	False	True
# DP05_0085PE	False	True
# DP05_0087E	False	True
# DP05_0086E	False	True
# DP05_0088M	False	True
# DP05_0086EA	False	True
# DP02_0153M	False	True
# DP02_0153E	False	True
# DP05_0087PMA	False	True
# DP04_0142EA	False	True
# DP04_0142E	False	True
# DP05_0087MA	False	True
# DP05_0084E	False	True
# DP05_0082EA	False	True
# DP05_0086PE	False	True
# DP02_0153PEA	False	True
# DP05_0089PM	False	True
# DP02_0153PM	False	True
# DP05_0088PMA	False	True
# DP05_0089PMA	False	True
# DP04_0143PEA	False	True
# DP05_0085PEA	False	True
# DP05_0083PE	False	True
# DP04_0143E	False	True
# DP05_0089M	False	True
# DP05_0083PEA	False	True
# DP05_0089EA	False	True
# DP05_0087PM	False	True
# DP04_0143M	False	True
# DP05_0087PE	False	True
# DP05_0084PEA	False	True
# DP05_0082PMA	False	True
# DP05_0083E	False	True
# DP05_0088PM	False	True
# DP05_0086PM	False	True
# DP05_0082PEA	False	True
# DP05_0084M	False	True
# DP04_0143PE	False	True
# DP04_0142MA	False	True
# DP05_0082PM	False	True
# DP05_0084PMA	False	True
# DP04_0143PM	False	True
# DP05_0086PMA	False	True
# DP05_0085MA	False	True
# DP05_0085PM	False	True
# DP05_0088EA	False	True
# DP05_0082E	False	True
# DP05_0087EA	False	True
# DP05_0084PM	False	True
# DP05_0089PEA	False	True
# DP02_0153PE	False	True
# DP05_0088MA	False	True
# DP05_0086PEA	False	True
# DP05_0085E	False	True
# DP05_0082PE	False	True
# DP05_0083MA	False	True
# DP04_0142PE	False	True
# DP05_0088PE	False	True
# DP05_0089E	False	True
# DP04_0142PMA	False	True
# DP04_0143MA	False	True

# %% [markdown]
# We can see that many variable codes were added in 2019.  There were no variable codes present in 2014 that were not present in 2019.

# %% [markdown]
# ## Task 4
#
# Using the results of tasks 1-3, create a list of variables common to both survey versions (and make sure that the variable codes consistently refer to the same labels) and filter both the 2014 and 2019 ACS datasets to include only those values.

# %%
variable_codes_in_both_years = acs_2014_variable_codes.intersection(acs_2019_variable_codes)
both_years_list = list(variable_codes_in_both_years)
for variable_code in both_years_list:
    val_in_2014 = acs_2014.loc[acs_2014['variable_code'] == variable_code].iloc[0]
    val_in_2019 = acs_2019.loc[acs_2019['variable_code'] == variable_code].iloc[0]
    if val_in_2014['label'] != val_in_2019['label']:
        print('{}\t{}\t{}'.format(variable_code, val_in_2014['label'], val_in_2019['label']))
# Out:
# DP05_0034PEA	Annotation of Percent!!RACE!!One race!!American Indian and Alaska Native	Annotation of Percent!!RACE!!Total population!!One race
# DP02_0017MA	Annotation of Margin of Error!!RELATIONSHIP!!Population in households	Annotation of Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Average family size
# DP05_0068PMA	Annotation of Percent Margin of Error!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)!!Puerto Rican	Annotation of Percent Margin of Error!!Race alone or in combination with one or more other races!!Total population!!Native Hawaiian and Other Pacific Islander
# DP04_0066PMA	Annotation of Percent Margin of Error!!HOUSE HEATING FUEL!!Occupied housing units!!Coal or coke	Annotation of Percent Margin of Error!!HOUSE HEATING FUEL!!Occupied housing units!!Fuel oil, kerosene, etc.
# DP05_0016E	Estimate!!SEX AND AGE!!85 years and over	Estimate!!SEX AND AGE!!Total population!!75 to 84 years
# DP03_0107PEA	Annotation of Percent!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population 18 to 64 years!!In labor force!!Employed!!With health insurance coverage!!With public coverage	Annotation of Percent!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population 19 to 64 years!!In labor force:!!Employed:!!With health insurance coverage!!With public coverage
# DP02_0020M	Margin of Error!!RELATIONSHIP!!Population in households!!Child	Margin of Error!!RELATIONSHIP!!Population in households!!Spouse
# DP02_0002PM	Percent Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Family households (families)	Percent Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Married-couple family
# DP05_0074MA	Annotation of Margin of Error!!HISPANIC OR LATINO AND RACE!!Total population!!Not Hispanic or Latino!!American Indian and Alaska Native alone	Annotation of Margin of Error!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)!!Cuban
# DP02_0062PEA	Annotation of Percent!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Some college, no degree	Annotation of Percent!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!High school graduate (includes equivalency)
# DP04_0104PMA	Annotation of Percent Margin of Error!!SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units without a mortgage!!$200 to $299	Annotation of Percent Margin of Error!!SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units without a mortgage!!$250 to $399
# DP02_0123PE	Percent!!ANCESTRY!!Total population!!American	Percent!!ANCESTRY!!Total population
# DP04_0021PEA	Annotation of Percent!!YEAR STRUCTURE BUILT!!Total housing units!!Built 1970 to 1979	Annotation of Percent!!YEAR STRUCTURE BUILT!!Total housing units!!Built 1980 to 1989
# DP02_0013MA	Annotation of Margin of Error!!HOUSEHOLDS BY TYPE!!Households with one or more people under 18 years	Annotation of Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Female householder, no spouse/partner present!!Householder living alone!!65 years and over
# DP02_0086PM	Percent Margin of Error!!PLACE OF BIRTH!!Total population	Percent Margin of Error!!RESIDENCE 1 YEAR AGO!!Population 1 year and over!!Abroad
# DP02_0089MA	Annotation of Margin of Error!!PLACE OF BIRTH!!Total population!!Native!!Born in United States!!State of residence	Annotation of Margin of Error!!PLACE OF BIRTH!!Total population!!Native!!Born in United States
# DP02_0120PMA	Annotation of Percent Margin of Error!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Other languages	Annotation of Percent Margin of Error!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Asian and Pacific Islander languages!!Speak English less than "very well"
# DP02_0033PMA	Annotation of Percent Margin of Error!!MARITAL STATUS!!Females 15 years and over!!Separated	Annotation of Percent Margin of Error!!MARITAL STATUS!!Females 15 years and over!!Now married, except separated
# DP03_0080EA	Annotation of Estimate!!INCOME AND BENEFITS (IN 2014 INFLATION-ADJUSTED DOLLARS)!!Families!!$35,000 to $49,999	Annotation of Estimate!!INCOME AND BENEFITS (IN 2019 INFLATION-ADJUSTED DOLLARS)!!Families!!$35,000 to $49,999
# DP04_0048M	Margin of Error!!HOUSING TENURE!!Average household size of renter-occupied unit	Margin of Error!!HOUSING TENURE!!Occupied housing units!!Average household size of owner-occupied unit
# DP02_0143M	Margin of Error!!ANCESTRY!!Total population!!Slovak	Margin of Error!!ANCESTRY!!Total population!!Scottish
# DP04_0030EA	Annotation of Estimate!!ROOMS!!Total housing units!!4 rooms	Annotation of Estimate!!ROOMS!!Total housing units!!3 rooms
# DP02_0004MA	Annotation of Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Family households (families)!!Married-couple family	Annotation of Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Cohabiting couple household
# DP05_0047MA	Annotation of Margin of Error!!RACE!!One race!!Native Hawaiian and Other Pacific Islander	Annotation of Margin of Error!!RACE!!Total population!!One race!!Asian!!Filipino
# DP02_0146E	Estimate!!ANCESTRY!!Total population!!Swiss	Estimate!!ANCESTRY!!Total population!!Swedish
# DP02_0064PM	Percent Margin of Error!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Bachelor's degree	Percent Margin of Error!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Associate's degree
# DP02_0058PMA	Annotation of Percent Margin of Error!!EDUCATIONAL ATTAINMENT!!Population 25 years and over	Annotation of Percent Margin of Error!!SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school
# DP02_0073PMA	Annotation of Percent Margin of Error!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!Under 18 years!!With a disability	Annotation of Percent Margin of Error!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!Under 18 years
# DP04_0024PE	Percent!!YEAR STRUCTURE BUILT!!Total housing units!!Built 1940 to 1949	Percent!!YEAR STRUCTURE BUILT!!Total housing units!!Built 1950 to 1959
# DP02_0095M	Margin of Error!!U.S. CITIZENSHIP STATUS!!Foreign-born population!!Not a U.S. citizen	Margin of Error!!U.S. CITIZENSHIP STATUS!!Foreign-born population!!Naturalized U.S. citizen
# DP02_0015PE	Percent!!HOUSEHOLDS BY TYPE!!Average household size	Percent!!HOUSEHOLDS BY TYPE!!Total households!!Households with one or more people 65 years and over
# DP02_0051PEA	Annotation of Percent!!GRANDPARENTS!!Number of grandparents responsible for own grandchildren under 18 years!!Who are married	Annotation of Percent!!GRANDPARENTS!!Number of grandparents responsible for own grandchildren under 18 years!!Who are female
# DP02_0065PEA	Annotation of Percent!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Graduate or professional degree	Annotation of Percent!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Bachelor's degree
# DP02_0036MA	Annotation of Margin of Error!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months	Annotation of Margin of Error!!MARITAL STATUS!!Females 15 years and over!!Divorced
# DP04_0091E	Estimate!!MORTGAGE STATUS!!Owner-occupied units!!Housing units without a mortgage	Estimate!!MORTGAGE STATUS!!Owner-occupied units!!Housing units with a mortgage
# DP05_0004MA	Annotation of Margin of Error!!SEX AND AGE!!Under 5 years	Annotation of Margin of Error!!SEX AND AGE!!Total population!!Sex ratio (males per 100 females)
# DP05_0058E	Estimate!!RACE!!Race alone or in combination with one or more other races!!Total population	Estimate!!RACE!!Total population!!Two or more races
# DP03_0070M	Margin of Error!!INCOME AND BENEFITS (IN 2014 INFLATION-ADJUSTED DOLLARS)!!With Supplemental Security Income	Margin of Error!!INCOME AND BENEFITS (IN 2019 INFLATION-ADJUSTED DOLLARS)!!Total households!!With Supplemental Security Income
# DP04_0034M	Margin of Error!!ROOMS!!Total housing units!!8 rooms	Margin of Error!!ROOMS!!Total housing units!!7 rooms
# DP05_0061EA	Annotation of Estimate!!RACE!!Race alone or in combination with one or more other races!!Total population!!American Indian and Alaska Native	Annotation of Estimate!!RACE!!Total population!!Two or more races!!White and Asian
# DP03_0101PEA	Annotation of Percent!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population under 18 years!!No health insurance coverage	Annotation of Percent!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population under 19 years!!No health insurance coverage
# DP04_0133PMA	Annotation of Percent Margin of Error!!GROSS RENT!!No rent paid	Annotation of Percent Margin of Error!!GROSS RENT!!Occupied units paying rent!!$3,000 or more
# DP02_0089M	Margin of Error!!PLACE OF BIRTH!!Total population!!Native!!Born in United States!!State of residence	Margin of Error!!PLACE OF BIRTH!!Total population!!Native!!Born in United States
# DP03_0111E	Estimate!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population 18 to 64 years!!In labor force!!Unemployed!!With health insurance coverage!!With private health insurance	Estimate!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population 19 to 64 years!!In labor force:!!Unemployed:!!With health insurance coverage!!With private health insurance
# DP03_0058M	Margin of Error!!INCOME AND BENEFITS (IN 2014 INFLATION-ADJUSTED DOLLARS)!!Total households!!$75,000 to $99,999	Margin of Error!!INCOME AND BENEFITS (IN 2019 INFLATION-ADJUSTED DOLLARS)!!Total households!!$75,000 to $99,999
# DP05_0036E	Estimate!!RACE!!One race!!American Indian and Alaska Native!!Chippewa tribal grouping	Estimate!!RACE!!Total population!!One race
# DP04_0066PM	Percent Margin of Error!!HOUSE HEATING FUEL!!Occupied housing units!!Coal or coke	Percent Margin of Error!!HOUSE HEATING FUEL!!Occupied housing units!!Fuel oil, kerosene, etc.
# DP04_0054EA	Annotation of Estimate!!YEAR HOUSEHOLDER MOVED INTO UNIT!!Occupied housing units!!Moved in 1970 to 1979	Annotation of Estimate!!YEAR HOUSEHOLDER MOVED INTO UNIT!!Occupied housing units!!Moved in 2000 to 2009
# DP02_0075EA	Annotation of Estimate!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!18 to 64 years!!With a disability	Annotation of Estimate!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!18 to 64 years
# DP02_0118PM	Percent Margin of Error!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Asian and Pacific Islander languages	Percent Margin of Error!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Other Indo-European languages!!Speak English less than "very well"
# DP02_0050E	Estimate!!GRANDPARENTS!!Number of grandparents responsible for own grandchildren under 18 years!!Who are female	Estimate!!GRANDPARENTS!!Number of grandparents responsible for own grandchildren under 18 years
# DP04_0027PEA	Annotation of Percent!!ROOMS!!Total housing units!!1 room	Annotation of Percent!!ROOMS!!Total housing units
# DP05_0013MA	Annotation of Margin of Error!!SEX AND AGE!!60 to 64 years	Annotation of Margin of Error!!SEX AND AGE!!Total population!!55 to 59 years
# DP05_0049EA	Annotation of Estimate!!RACE!!One race!!Native Hawaiian and Other Pacific Islander!!Guamanian or Chamorro	Annotation of Estimate!!RACE!!Total population!!One race!!Asian!!Korean
# DP02_0027EA	Annotation of Estimate!!MARITAL STATUS!!Males 15 years and over!!Separated	Annotation of Estimate!!MARITAL STATUS!!Males 15 years and over!!Now married, except separated
# DP05_0015EA	Annotation of Estimate!!SEX AND AGE!!75 to 84 years	Annotation of Estimate!!SEX AND AGE!!Total population!!65 to 74 years
# DP04_0132PMA	Annotation of Percent Margin of Error!!GROSS RENT!!Occupied units paying rent!!Median (dollars)	Annotation of Percent Margin of Error!!GROSS RENT!!Occupied units paying rent!!$2,500 to $2,999
# DP04_0103M	Margin of Error!!SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units without a mortgage!!$100 to $199	Margin of Error!!SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units without a mortgage!!Less than $250
# DP02_0124E	Estimate!!ANCESTRY!!Total population!!Arab	Estimate!!ANCESTRY!!Total population!!American
# DP04_0020PMA	Annotation of Percent Margin of Error!!YEAR STRUCTURE BUILT!!Total housing units!!Built 1980 to 1989	Annotation of Percent Margin of Error!!YEAR STRUCTURE BUILT!!Total housing units!!Built 1990 to 1999
# DP02_0005MA	Annotation of Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Family households (families)!!Married-couple family!!With own children under 18 years	Annotation of Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Cohabiting couple household!!With own children of the householder under 18 years
# DP04_0086MA	Annotation of Margin of Error!!VALUE!!Owner-occupied units!!$500,000 to $999,999	Annotation of Margin of Error!!VALUE!!Owner-occupied units!!$300,000 to $499,999
# DP04_0072PEA	Annotation of Percent!!SELECTED CHARACTERISTICS!!Occupied housing units!!Lacking complete plumbing facilities	Annotation of Percent!!SELECTED CHARACTERISTICS!!Occupied housing units
# DP05_0070M	Margin of Error!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)!!Other Hispanic or Latino	Margin of Error!!HISPANIC OR LATINO AND RACE!!Total population
# DP02_0053PE	Percent!!SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school, preschool	Percent!!SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school
# DP03_0127E	Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!Families with female householder, no husband present!!With related children under 18 years!!With related children under 5 years only	Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All families!!Families with female householder, no spouse present!!With related children of the householder under 18 years!!With related children of the householder under 5 years only
# DP05_0077PE	Percent!!HISPANIC OR LATINO AND RACE!!Total population!!Not Hispanic or Latino!!Some other race alone	Percent!!HISPANIC OR LATINO AND RACE!!Total population!!Not Hispanic or Latino!!White alone
# DP03_0106PEA	Annotation of Percent!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population 18 to 64 years!!In labor force!!Employed!!With health insurance coverage!!With private health insurance	Annotation of Percent!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population 19 to 64 years!!In labor force:!!Employed:!!With health insurance coverage!!With private health insurance
# DP04_0109PM	Percent Margin of Error!!SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI)!!Housing units with a mortgage (excluding units where SMOCAPI cannot be computed)!!Less than 20.0 percent	Percent Margin of Error!!SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units without a mortgage!!Median (dollars)
# DP04_0089MA	Annotation of Margin of Error!!MORTGAGE STATUS!!Owner-occupied units	Annotation of Margin of Error!!VALUE!!Owner-occupied units!!Median (dollars)
# DP03_0081PM	Percent Margin of Error!!INCOME AND BENEFITS (IN 2014 INFLATION-ADJUSTED DOLLARS)!!Families!!$50,000 to $74,999	Percent Margin of Error!!INCOME AND BENEFITS (IN 2019 INFLATION-ADJUSTED DOLLARS)!!Families!!$50,000 to $74,999
# DP05_0004E	Estimate!!SEX AND AGE!!Under 5 years	Estimate!!SEX AND AGE!!Total population!!Sex ratio (males per 100 females)
# DP03_0105PMA	Annotation of Percent Margin of Error!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population 18 to 64 years!!In labor force!!Employed!!With health insurance coverage	Annotation of Percent Margin of Error!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population 19 to 64 years!!In labor force:!!Employed:!!With health insurance coverage
# DP05_0064M	Margin of Error!!RACE!!Race alone or in combination with one or more other races!!Total population!!Some other race	Margin of Error!!Race alone or in combination with one or more other races!!Total population!!White
# DP02_0094PE	Percent!!U.S. CITIZENSHIP STATUS!!Foreign-born population!!Naturalized U.S. citizen	Percent!!U.S. CITIZENSHIP STATUS!!Foreign-born population
# DP02_0048PEA	Annotation of Percent!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Years responsible for grandchildren!!5 or more years	Annotation of Percent!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Years responsible for grandchildren!!3 or 4 years
# DP03_0126MA	Annotation of Margin of Error!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!Families with female householder, no husband present!!With related children under 18 years	Annotation of Margin of Error!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All families!!Families with female householder, no spouse present!!With related children of the householder under 18 years
# DP03_0072EA	Annotation of Estimate!!INCOME AND BENEFITS (IN 2014 INFLATION-ADJUSTED DOLLARS)!!With cash public assistance income	Annotation of Estimate!!INCOME AND BENEFITS (IN 2019 INFLATION-ADJUSTED DOLLARS)!!Total households!!With cash public assistance income
# DP04_0084PE	Percent!!VALUE!!Owner-occupied units!!$200,000 to $299,999	Percent!!VALUE!!Owner-occupied units!!$150,000 to $199,999
# DP04_0133M	Margin of Error!!GROSS RENT!!No rent paid	Margin of Error!!GROSS RENT!!Occupied units paying rent!!$3,000 or more
# DP02_0052M	Margin of Error!!SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school	Margin of Error!!GRANDPARENTS!!Number of grandparents responsible for own grandchildren under 18 years!!Who are married
# DP04_0050PEA	Annotation of Percent!!YEAR HOUSEHOLDER MOVED INTO UNIT!!Occupied housing units!!Moved in 2010 or later	Annotation of Percent!!YEAR HOUSEHOLDER MOVED INTO UNIT!!Occupied housing units
# DP02_0002E	Estimate!!HOUSEHOLDS BY TYPE!!Total households!!Family households (families)	Estimate!!HOUSEHOLDS BY TYPE!!Total households!!Married-couple family
# DP03_0103MA	Annotation of Margin of Error!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population 18 to 64 years!!In labor force	Annotation of Margin of Error!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population 19 to 64 years!!In labor force:
# DP04_0099PEA	Annotation of Percent!!SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units with a mortgage!!$2,000 or more	Annotation of Percent!!SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units with a mortgage!!$2,500 to $2,999
# DP04_0099E	Estimate!!SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units with a mortgage!!$2,000 or more	Estimate!!SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units with a mortgage!!$2,500 to $2,999
# DP05_0050PMA	Annotation of Percent Margin of Error!!RACE!!One race!!Native Hawaiian and Other Pacific Islander!!Samoan	Annotation of Percent Margin of Error!!RACE!!Total population!!One race!!Asian!!Vietnamese
# DP02_0053PEA	Annotation of Percent!!SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school, preschool	Annotation of Percent!!SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school
# DP02_0045PM	Percent Margin of Error!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Years responsible for grandchildren!!Less than 1 year	Percent Margin of Error!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Grandparents responsible for grandchildren
# DP02_0018E	Estimate!!RELATIONSHIP!!Population in households!!Householder	Estimate!!RELATIONSHIP!!Population in households
# DP02_0098PE	Percent!!YEAR OF ENTRY!!Native!!Entered 2010 or later	Percent!!YEAR OF ENTRY!!Population born outside the United States!!Native
# DP02_0097M	Margin of Error!!YEAR OF ENTRY!!Native	Margin of Error!!YEAR OF ENTRY!!Population born outside the United States
# DP02_0146M	Margin of Error!!ANCESTRY!!Total population!!Swiss	Margin of Error!!ANCESTRY!!Total population!!Swedish
# DP02_0109MA	Annotation of Margin of Error!!WORLD REGION OF BIRTH OF FOREIGN BORN!!Foreign-born population, excluding population born at sea!!Northern America	Annotation of Margin of Error!!WORLD REGION OF BIRTH OF FOREIGN BORN!!Foreign-born population, excluding population born at sea!!Latin America
# DP05_0006PE	Percent!!SEX AND AGE!!10 to 14 years	Percent!!SEX AND AGE!!Total population!!5 to 9 years
# DP04_0113MA	Annotation of Margin of Error!!SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI)!!Housing units with a mortgage (excluding units where SMOCAPI cannot be computed)!!35.0 percent or more	Annotation of Margin of Error!!SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI)!!Housing units with a mortgage (excluding units where SMOCAPI cannot be computed)!!25.0 to 29.9 percent
# DP05_0032M	Margin of Error!!RACE!!One race!!White	Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)
# DP04_0065MA	Annotation of Margin of Error!!HOUSE HEATING FUEL!!Occupied housing units!!Fuel oil, kerosene, etc.	Annotation of Margin of Error!!HOUSE HEATING FUEL!!Occupied housing units!!Electricity
# DP04_0133EA	Annotation of Estimate!!GROSS RENT!!No rent paid	Annotation of Estimate!!GROSS RENT!!Occupied units paying rent!!$3,000 or more
# DP03_0076MA	Annotation of Margin of Error!!INCOME AND BENEFITS (IN 2014 INFLATION-ADJUSTED DOLLARS)!!Families!!Less than $10,000	Annotation of Margin of Error!!INCOME AND BENEFITS (IN 2019 INFLATION-ADJUSTED DOLLARS)!!Families!!Less than $10,000
# DP03_0114M	Margin of Error!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population 18 to 64 years!!Not in labor force	Margin of Error!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population 19 to 64 years!!Not in labor force:
# DP05_0023PE	Percent!!SEX AND AGE!!18 years and over!!Male	Percent!!SEX AND AGE!!Total population!!62 years and over
# DP02_0041EA	Annotation of Estimate!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months!!Per 1,000 women 20 to 34 years old	Annotation of Estimate!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months!!Per 1,000 women 15 to 19 years old
# DP04_0049PM	Percent Margin of Error!!YEAR HOUSEHOLDER MOVED INTO UNIT!!Occupied housing units	Percent Margin of Error!!HOUSING TENURE!!Occupied housing units!!Average household size of renter-occupied unit
# DP05_0059M	Margin of Error!!RACE!!Race alone or in combination with one or more other races!!Total population!!White	Margin of Error!!RACE!!Total population!!Two or more races!!White and Black or African American
# DP02_0129PMA	Annotation of Percent Margin of Error!!ANCESTRY!!Total population!!French (except Basque)	Annotation of Percent Margin of Error!!ANCESTRY!!Total population!!English
# DP03_0078E	Estimate!!INCOME AND BENEFITS (IN 2014 INFLATION-ADJUSTED DOLLARS)!!Families!!$15,000 to $24,999	Estimate!!INCOME AND BENEFITS (IN 2019 INFLATION-ADJUSTED DOLLARS)!!Families!!$15,000 to $24,999
# DP04_0111EA	Annotation of Estimate!!SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI)!!Housing units with a mortgage (excluding units where SMOCAPI cannot be computed)!!25.0 to 29.9 percent	Annotation of Estimate!!SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI)!!Housing units with a mortgage (excluding units where SMOCAPI cannot be computed)!!Less than 20.0 percent
# DP04_0087PM	Percent Margin of Error!!VALUE!!Owner-occupied units!!$1,000,000 or more	Percent Margin of Error!!VALUE!!Owner-occupied units!!$500,000 to $999,999
# DP02_0008MA	Annotation of Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Family households (families)!!Female householder, no husband present, family	Annotation of Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Male householder, no spouse/partner present!!Householder living alone
# DP02_0049PMA	Annotation of Percent Margin of Error!!GRANDPARENTS!!Number of grandparents responsible for own grandchildren under 18 years	Annotation of Percent Margin of Error!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Years responsible for grandchildren!!5 or more years
# DP03_0066PM	Percent Margin of Error!!INCOME AND BENEFITS (IN 2014 INFLATION-ADJUSTED DOLLARS)!!With Social Security	Percent Margin of Error!!INCOME AND BENEFITS (IN 2019 INFLATION-ADJUSTED DOLLARS)!!Total households!!With Social Security
# DP04_0065PM	Percent Margin of Error!!HOUSE HEATING FUEL!!Occupied housing units!!Fuel oil, kerosene, etc.	Percent Margin of Error!!HOUSE HEATING FUEL!!Occupied housing units!!Electricity
# DP03_0129PMA	Annotation of Percent Margin of Error!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!Under 18 years	Annotation of Percent Margin of Error!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All people!!Under 18 years
# DP05_0023MA	Annotation of Margin of Error!!SEX AND AGE!!18 years and over!!Male	Annotation of Margin of Error!!SEX AND AGE!!Total population!!62 years and over
# DP03_0089MA	Annotation of Margin of Error!!INCOME AND BENEFITS (IN 2014 INFLATION-ADJUSTED DOLLARS)!!Nonfamily households	Annotation of Margin of Error!!INCOME AND BENEFITS (IN 2019 INFLATION-ADJUSTED DOLLARS)!!Nonfamily households
# DP04_0044EA	Annotation of Estimate!!HOUSING TENURE!!Occupied housing units	Annotation of Estimate!!BEDROOMS!!Total housing units!!5 or more bedrooms
# DP03_0051M	Margin of Error!!INCOME AND BENEFITS (IN 2014 INFLATION-ADJUSTED DOLLARS)!!Total households	Margin of Error!!INCOME AND BENEFITS (IN 2019 INFLATION-ADJUSTED DOLLARS)!!Total households
# DP02_0075PMA	Annotation of Percent Margin of Error!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!18 to 64 years!!With a disability	Annotation of Percent Margin of Error!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!18 to 64 years
# DP02_0059MA	Annotation of Margin of Error!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Less than 9th grade	Annotation of Margin of Error!!EDUCATIONAL ATTAINMENT!!Population 25 years and over
# DP02_0126MA	Annotation of Margin of Error!!ANCESTRY!!Total population!!Danish	Annotation of Margin of Error!!ANCESTRY!!Total population!!Czech
# DP02_0040E	Estimate!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months!!Per 1,000 women 15 to 19 years old	Estimate!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months!!Per 1,000 women 15 to 50 years old
# DP02_0148M	Margin of Error!!ANCESTRY!!Total population!!Welsh	Margin of Error!!ANCESTRY!!Total population!!Ukrainian
# DP02_0040PM	Percent Margin of Error!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months!!Per 1,000 women 15 to 19 years old	Percent Margin of Error!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months!!Per 1,000 women 15 to 50 years old
# DP04_0092EA	Annotation of Estimate!!SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units with a mortgage	Annotation of Estimate!!MORTGAGE STATUS!!Owner-occupied units!!Housing units without a mortgage
# DP02_0009EA	Annotation of Estimate!!HOUSEHOLDS BY TYPE!!Total households!!Family households (families)!!Female householder, no husband present, family!!With own children under 18 years	Annotation of Estimate!!HOUSEHOLDS BY TYPE!!Total households!!Male householder, no spouse/partner present!!Householder living alone!!65 years and over
# DP02_0078M	Margin of Error!!RESIDENCE 1 YEAR AGO!!Population 1 year and over	Margin of Error!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!65 years and over!!With a disability
# DP03_0111EA	Annotation of Estimate!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population 18 to 64 years!!In labor force!!Unemployed!!With health insurance coverage!!With private health insurance	Annotation of Estimate!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population 19 to 64 years!!In labor force:!!Unemployed:!!With health insurance coverage!!With private health insurance
# DP04_0023PM	Percent Margin of Error!!YEAR STRUCTURE BUILT!!Total housing units!!Built 1950 to 1959	Percent Margin of Error!!YEAR STRUCTURE BUILT!!Total housing units!!Built 1960 to 1969
# DP04_0141PMA	Annotation of Percent Margin of Error!!GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!Not computed	Annotation of Percent Margin of Error!!GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!Occupied units paying rent (excluding units where GRAPI cannot be computed)!!30.0 to 34.9 percent
# DP02_0087PMA	Annotation of Percent Margin of Error!!PLACE OF BIRTH!!Total population!!Native	Annotation of Percent Margin of Error!!PLACE OF BIRTH!!Total population
# DP03_0133PM	Percent Margin of Error!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!18 years and over	Percent Margin of Error!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All people!!18 years and over
# DP03_0110PMA	Annotation of Percent Margin of Error!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population 18 to 64 years!!In labor force!!Unemployed!!With health insurance coverage	Annotation of Percent Margin of Error!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population 19 to 64 years!!In labor force:!!Unemployed:!!With health insurance coverage
# DP04_0116E	Estimate!!SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI)!!Housing unit without a mortgage (excluding units where SMOCAPI cannot be computed)!!Less than 10.0 percent	Estimate!!SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI)!!Housing units with a mortgage (excluding units where SMOCAPI cannot be computed)!!Not computed
# DP02_0137PEA	Annotation of Percent!!ANCESTRY!!Total population!!Norwegian	Annotation of Percent!!ANCESTRY!!Total population!!Lithuanian
# DP04_0136E	Estimate!!GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!Occupied units paying rent (excluding units where GRAPI cannot be computed)!!15.0 to 19.9 percent	Estimate!!GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!Occupied units paying rent (excluding units where GRAPI cannot be computed)
# DP04_0037EA	Annotation of Estimate!!BEDROOMS!!Total housing units	Annotation of Estimate!!ROOMS!!Total housing units!!Median rooms
# DP03_0112PMA	Annotation of Percent Margin of Error!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population 18 to 64 years!!In labor force!!Unemployed!!With health insurance coverage!!With public coverage	Annotation of Percent Margin of Error!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population 19 to 64 years!!In labor force:!!Unemployed:!!With health insurance coverage!!With public coverage
# DP05_0034MA	Annotation of Margin of Error!!RACE!!One race!!American Indian and Alaska Native	Annotation of Margin of Error!!RACE!!Total population!!One race
# DP02_0066PE	Percent!!EDUCATIONAL ATTAINMENT!!Percent high school graduate or higher	Percent!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Graduate or professional degree
# DP04_0092MA	Annotation of Margin of Error!!SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units with a mortgage	Annotation of Margin of Error!!MORTGAGE STATUS!!Owner-occupied units!!Housing units without a mortgage
# DP05_0066PEA	Annotation of Percent!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)	Annotation of Percent!!Race alone or in combination with one or more other races!!Total population!!American Indian and Alaska Native
# DP03_0058PE	Percent!!INCOME AND BENEFITS (IN 2014 INFLATION-ADJUSTED DOLLARS)!!Total households!!$75,000 to $99,999	Percent!!INCOME AND BENEFITS (IN 2019 INFLATION-ADJUSTED DOLLARS)!!Total households!!$75,000 to $99,999
# DP03_0009PM	Percent Margin of Error!!EMPLOYMENT STATUS!!Civilian labor force!!Percent Unemployed	Percent Margin of Error!!EMPLOYMENT STATUS!!Civilian labor force!!Unemployment Rate
# DP05_0044MA	Annotation of Margin of Error!!RACE!!One race!!Asian!!Korean	Annotation of Margin of Error!!RACE!!Total population!!One race!!Asian
# DP03_0123E	Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!Married couple families!!With related children under 18 years	Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All families!!Married couple families!!With related children of the householder under 18 years
# DP04_0066PEA	Annotation of Percent!!HOUSE HEATING FUEL!!Occupied housing units!!Coal or coke	Annotation of Percent!!HOUSE HEATING FUEL!!Occupied housing units!!Fuel oil, kerosene, etc.
# DP02_0132PM	Percent Margin of Error!!ANCESTRY!!Total population!!Greek	Percent Margin of Error!!ANCESTRY!!Total population!!German
# DP03_0131MA	Annotation of Margin of Error!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!Under 18 years!!Related children under 18 years!!Related children under 5 years	Annotation of Margin of Error!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All people!!Under 18 years!!Related children of the householder under 18 years!!Related children of the householder under 5 years
# DP05_0010PE	Percent!!SEX AND AGE!!35 to 44 years	Percent!!SEX AND AGE!!Total population!!25 to 34 years
# DP05_0049PMA	Annotation of Percent Margin of Error!!RACE!!One race!!Native Hawaiian and Other Pacific Islander!!Guamanian or Chamorro	Annotation of Percent Margin of Error!!RACE!!Total population!!One race!!Asian!!Korean
# DP02_0109M	Margin of Error!!WORLD REGION OF BIRTH OF FOREIGN BORN!!Foreign-born population, excluding population born at sea!!Northern America	Margin of Error!!WORLD REGION OF BIRTH OF FOREIGN BORN!!Foreign-born population, excluding population born at sea!!Latin America
# DP05_0069M	Margin of Error!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)!!Cuban	Margin of Error!!Race alone or in combination with one or more other races!!Total population!!Some other race
# DP02_0150PMA	Annotation of Percent Margin of Error!!COMPUTERS AND INTERNET USE!!Total Households	Annotation of Percent Margin of Error!!ANCESTRY!!Total population!!West Indian (excluding Hispanic origin groups)
# DP02_0074PMA	Annotation of Percent Margin of Error!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!18 to 64 years	Annotation of Percent Margin of Error!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!Under 18 years!!With a disability
# DP04_0084PMA	Annotation of Percent Margin of Error!!VALUE!!Owner-occupied units!!$200,000 to $299,999	Annotation of Percent Margin of Error!!VALUE!!Owner-occupied units!!$150,000 to $199,999
# DP05_0028PM	Percent Margin of Error!!RACE!!Total population	Percent Margin of Error!!SEX AND AGE!!Total population!!18 years and over!!Sex ratio (males per 100 females)
# DP04_0041PMA	Annotation of Percent Margin of Error!!BEDROOMS!!Total housing units!!3 bedrooms	Annotation of Percent Margin of Error!!BEDROOMS!!Total housing units!!2 bedrooms
# DP02_0031MA	Annotation of Margin of Error!!MARITAL STATUS!!Females 15 years and over!!Never married	Annotation of Margin of Error!!MARITAL STATUS!!Females 15 years and over
# DP04_0018M	Margin of Error!!YEAR STRUCTURE BUILT!!Total housing units!!Built 2000 to 2009	Margin of Error!!YEAR STRUCTURE BUILT!!Total housing units!!Built 2010 to 2013
# DP02_0094MA	Annotation of Margin of Error!!U.S. CITIZENSHIP STATUS!!Foreign-born population!!Naturalized U.S. citizen	Annotation of Margin of Error!!U.S. CITIZENSHIP STATUS!!Foreign-born population
# DP02_0064PEA	Annotation of Percent!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Bachelor's degree	Annotation of Percent!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Associate's degree
# DP04_0129PEA	Annotation of Percent!!GROSS RENT!!Occupied units paying rent!!$750 to $999	Annotation of Percent!!GROSS RENT!!Occupied units paying rent!!$1,000 to $1,499
# DP04_0005M	Margin of Error!!HOUSING OCCUPANCY!!Rental vacancy rate	Margin of Error!!HOUSING OCCUPANCY!!Total housing units!!Rental vacancy rate
# DP02_0067M	Margin of Error!!EDUCATIONAL ATTAINMENT!!Percent bachelor's degree or higher	Margin of Error!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!High school graduate or higher
# DP04_0104EA	Annotation of Estimate!!SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units without a mortgage!!$200 to $299	Annotation of Estimate!!SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units without a mortgage!!$250 to $399
# DP02_0119PMA	Annotation of Percent Margin of Error!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Asian and Pacific Islander languages!!Speak English less than "very well"	Annotation of Percent Margin of Error!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Asian and Pacific Islander languages
# DP03_0071PM	Percent Margin of Error!!INCOME AND BENEFITS (IN 2014 INFLATION-ADJUSTED DOLLARS)!!With Supplemental Security Income!!Mean Supplemental Security Income (dollars)	Percent Margin of Error!!INCOME AND BENEFITS (IN 2019 INFLATION-ADJUSTED DOLLARS)!!Total households!!With Supplemental Security Income!!Mean Supplemental Security Income (dollars)
# DP02_0021PE	Percent!!RELATIONSHIP!!Population in households!!Other relatives	Percent!!RELATIONSHIP!!Population in households!!Unmarried partner
# DP04_0040PE	Percent!!BEDROOMS!!Total housing units!!2 bedrooms	Percent!!BEDROOMS!!Total housing units!!1 bedroom
# DP03_0137M	Margin of Error!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!65 years and over!!Unrelated individuals 15 years and over	Margin of Error!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All people!!Unrelated individuals 15 years and over
# DP04_0068E	Estimate!!HOUSE HEATING FUEL!!Occupied housing units!!Solar energy	Estimate!!HOUSE HEATING FUEL!!Occupied housing units!!Wood
# DP04_0140PEA	Annotation of Percent!!GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!Occupied units paying rent (excluding units where GRAPI cannot be computed)!!35.0 percent or more	Annotation of Percent!!GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!Occupied units paying rent (excluding units where GRAPI cannot be computed)!!25.0 to 29.9 percent
# DP05_0039PEA	Annotation of Percent!!RACE!!One race!!Asian	Annotation of Percent!!RACE!!Total population!!One race!!American Indian and Alaska Native
# DP03_0093M	Margin of Error!!INCOME AND BENEFITS (IN 2014 INFLATION-ADJUSTED DOLLARS)!!Median earnings for male full-time, year-round workers (dollars)	Margin of Error!!INCOME AND BENEFITS (IN 2019 INFLATION-ADJUSTED DOLLARS)!!Median earnings for male full-time, year-round workers (dollars)
# DP03_0079M	Margin of Error!!INCOME AND BENEFITS (IN 2014 INFLATION-ADJUSTED DOLLARS)!!Families!!$25,000 to $34,999	Margin of Error!!INCOME AND BENEFITS (IN 2019 INFLATION-ADJUSTED DOLLARS)!!Families!!$25,000 to $34,999
# DP04_0083PMA	Annotation of Percent Margin of Error!!VALUE!!Owner-occupied units!!$150,000 to $199,999	Annotation of Percent Margin of Error!!VALUE!!Owner-occupied units!!$100,000 to $149,999
# DP05_0017PEA	Annotation of Percent!!SEX AND AGE!!Median age (years)	Annotation of Percent!!SEX AND AGE!!Total population!!85 years and over
# DP02_0045PMA	Annotation of Percent Margin of Error!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Years responsible for grandchildren!!Less than 1 year	Annotation of Percent Margin of Error!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Grandparents responsible for grandchildren
# DP02_0115E	Estimate!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Spanish!!Speak English less than "very well"	Estimate!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Spanish
# DP02_0142PE	Percent!!ANCESTRY!!Total population!!Scottish	Percent!!ANCESTRY!!Total population!!Scotch-Irish
# DP04_0097PE	Percent!!SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units with a mortgage!!$1,000 to $1,499	Percent!!SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units with a mortgage!!$1,500 to $1,999
# DP04_0069PM	Percent Margin of Error!!HOUSE HEATING FUEL!!Occupied housing units!!Other fuel	Percent Margin of Error!!HOUSE HEATING FUEL!!Occupied housing units!!Solar energy
# DP03_0064M	Margin of Error!!INCOME AND BENEFITS (IN 2014 INFLATION-ADJUSTED DOLLARS)!!With earnings	Margin of Error!!INCOME AND BENEFITS (IN 2019 INFLATION-ADJUSTED DOLLARS)!!Total households!!With earnings
# DP02_0080E	Estimate!!RESIDENCE 1 YEAR AGO!!Population 1 year and over!!Different house in the U.S.	Estimate!!RESIDENCE 1 YEAR AGO!!Population 1 year and over!!Same house
# DP05_0034PE	Percent!!RACE!!One race!!American Indian and Alaska Native	Percent!!RACE!!Total population!!One race
# DP04_0062M	Margin of Error!!HOUSE HEATING FUEL!!Occupied housing units!!Utility gas	Margin of Error!!HOUSE HEATING FUEL!!Occupied housing units
# DP02_0141M	Margin of Error!!ANCESTRY!!Total population!!Scotch-Irish	Margin of Error!!ANCESTRY!!Total population!!Russian
# DP02_0145EA	Annotation of Estimate!!ANCESTRY!!Total population!!Swedish	Annotation of Estimate!!ANCESTRY!!Total population!!Subsaharan African
# DP04_0019M	Margin of Error!!YEAR STRUCTURE BUILT!!Total housing units!!Built 1990 to 1999	Margin of Error!!YEAR STRUCTURE BUILT!!Total housing units!!Built 2000 to 2009
# DP02_0046E	Estimate!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Years responsible for grandchildren!!1 or 2 years	Estimate!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Years responsible for grandchildren!!Less than 1 year
# DP05_0057PMA	Annotation of Percent Margin of Error!!RACE!!Two or more races!!Black or African American and American Indian and Alaska Native	Annotation of Percent Margin of Error!!RACE!!Total population!!One race!!Some other race
# DP02_0099E	Estimate!!YEAR OF ENTRY!!Native!!Entered before 2010	Estimate!!YEAR OF ENTRY!!Population born outside the United States!!Native!!Entered 2010 or later
# DP05_0018EA	Annotation of Estimate!!SEX AND AGE!!18 years and over	Annotation of Estimate!!SEX AND AGE!!Total population!!Median age (years)
# DP04_0036E	Estimate!!ROOMS!!Total housing units!!Median rooms	Estimate!!ROOMS!!Total housing units!!9 rooms or more
# DP04_0040E	Estimate!!BEDROOMS!!Total housing units!!2 bedrooms	Estimate!!BEDROOMS!!Total housing units!!1 bedroom
# DP02_0024MA	Annotation of Margin of Error!!MARITAL STATUS!!Males 15 years and over	Annotation of Margin of Error!!RELATIONSHIP!!Population in households!!Other nonrelatives
# DP02_0090PM	Percent Margin of Error!!PLACE OF BIRTH!!Total population!!Native!!Born in United States!!Different state	Percent Margin of Error!!PLACE OF BIRTH!!Total population!!Native!!Born in United States!!State of residence
# DP05_0006EA	Annotation of Estimate!!SEX AND AGE!!10 to 14 years	Annotation of Estimate!!SEX AND AGE!!Total population!!5 to 9 years
# DP04_0084E	Estimate!!VALUE!!Owner-occupied units!!$200,000 to $299,999	Estimate!!VALUE!!Owner-occupied units!!$150,000 to $199,999
# DP04_0051PM	Percent Margin of Error!!YEAR HOUSEHOLDER MOVED INTO UNIT!!Occupied housing units!!Moved in 2000 to 2009	Percent Margin of Error!!YEAR HOUSEHOLDER MOVED INTO UNIT!!Occupied housing units!!Moved in 2017 or later
# DP04_0139M	Margin of Error!!GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!Occupied units paying rent (excluding units where GRAPI cannot be computed)!!30.0 to 34.9 percent	Margin of Error!!GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!Occupied units paying rent (excluding units where GRAPI cannot be computed)!!20.0 to 24.9 percent
# DP02_0046EA	Annotation of Estimate!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Years responsible for grandchildren!!1 or 2 years	Annotation of Estimate!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Years responsible for grandchildren!!Less than 1 year
# DP05_0005PMA	Annotation of Percent Margin of Error!!SEX AND AGE!!5 to 9 years	Annotation of Percent Margin of Error!!SEX AND AGE!!Total population!!Under 5 years
# DP02_0064MA	Annotation of Margin of Error!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Bachelor's degree	Annotation of Margin of Error!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Associate's degree
# DP03_0074PE	Percent!!INCOME AND BENEFITS (IN 2014 INFLATION-ADJUSTED DOLLARS)!!With Food Stamp/SNAP benefits in the past 12 months	Percent!!INCOME AND BENEFITS (IN 2019 INFLATION-ADJUSTED DOLLARS)!!Total households!!With Food Stamp/SNAP benefits in the past 12 months
# DP02_0060E	Estimate!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!9th to 12th grade, no diploma	Estimate!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Less than 9th grade
# DP02_0080MA	Annotation of Margin of Error!!RESIDENCE 1 YEAR AGO!!Population 1 year and over!!Different house in the U.S.	Annotation of Margin of Error!!RESIDENCE 1 YEAR AGO!!Population 1 year and over!!Same house
# DP02_0039PM	Percent Margin of Error!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months!!Per 1,000 women 15 to 50 years old	Percent Margin of Error!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months!!Unmarried women (widowed, divorced, and never married)!!Per 1,000 unmarried women
# DP03_0130E	Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!Under 18 years!!Related children under 18 years	Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All people!!Under 18 years!!Related children of the householder under 18 years
# DP05_0006MA	Annotation of Margin of Error!!SEX AND AGE!!10 to 14 years	Annotation of Margin of Error!!SEX AND AGE!!Total population!!5 to 9 years
# DP03_0137PEA	Annotation of Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!65 years and over!!Unrelated individuals 15 years and over	Annotation of Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All people!!Unrelated individuals 15 years and over
# DP02_0044E	Estimate!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Responsible for grandchildren	Estimate!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years
# DP05_0029MA	Annotation of Margin of Error!!RACE!!Total population!!One race	Annotation of Margin of Error!!SEX AND AGE!!Total population!!65 years and over
# DP02_0142M	Margin of Error!!ANCESTRY!!Total population!!Scottish	Margin of Error!!ANCESTRY!!Total population!!Scotch-Irish
# DP02_0045MA	Annotation of Margin of Error!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Years responsible for grandchildren!!Less than 1 year	Annotation of Margin of Error!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Grandparents responsible for grandchildren
# DP05_0007PEA	Annotation of Percent!!SEX AND AGE!!15 to 19 years	Annotation of Percent!!SEX AND AGE!!Total population!!10 to 14 years
# DP04_0040PEA	Annotation of Percent!!BEDROOMS!!Total housing units!!2 bedrooms	Annotation of Percent!!BEDROOMS!!Total housing units!!1 bedroom
# DP02_0072MA	Annotation of Margin of Error!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!Under 18 years	Annotation of Margin of Error!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!Total Civilian Noninstitutionalized Population!!With a disability
# DP02_0143PMA	Annotation of Percent Margin of Error!!ANCESTRY!!Total population!!Slovak	Annotation of Percent Margin of Error!!ANCESTRY!!Total population!!Scottish
# ...
# DP03_0068E	Estimate!!INCOME AND BENEFITS (IN 2014 INFLATION-ADJUSTED DOLLARS)!!With retirement income	Estimate!!INCOME AND BENEFITS (IN 2019 INFLATION-ADJUSTED DOLLARS)!!Total households!!With retirement income
# DP04_0102E	Estimate!!SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units without a mortgage!!Less than $100	Estimate!!SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units without a mortgage
# DP05_0037EA	Annotation of Estimate!!RACE!!One race!!American Indian and Alaska Native!!Navajo tribal grouping	Annotation of Estimate!!RACE!!Total population!!One race!!White
# DP04_0119PE	Percent!!SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI)!!Housing unit without a mortgage (excluding units where SMOCAPI cannot be computed)!!20.0 to 24.9 percent	Percent!!SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI)!!Housing unit without a mortgage (excluding units where SMOCAPI cannot be computed)!!10.0 to 14.9 percent
# DP05_0063PEA	Annotation of Percent!!RACE!!Race alone or in combination with one or more other races!!Total population!!Native Hawaiian and Other Pacific Islander	Annotation of Percent!!Race alone or in combination with one or more other races!!Total population
# DP02_0100MA	Annotation of Margin of Error!!YEAR OF ENTRY!!Foreign born	Annotation of Margin of Error!!YEAR OF ENTRY!!Population born outside the United States!!Native!!Entered before 2010
# DP03_0092MA	Annotation of Margin of Error!!INCOME AND BENEFITS (IN 2014 INFLATION-ADJUSTED DOLLARS)!!Median earnings for workers (dollars)	Annotation of Margin of Error!!INCOME AND BENEFITS (IN 2019 INFLATION-ADJUSTED DOLLARS)!!Median earnings for workers (dollars)
# DP04_0139PMA	Annotation of Percent Margin of Error!!GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!Occupied units paying rent (excluding units where GRAPI cannot be computed)!!30.0 to 34.9 percent	Annotation of Percent Margin of Error!!GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!Occupied units paying rent (excluding units where GRAPI cannot be computed)!!20.0 to 24.9 percent
# DP02_0070PM	Percent Margin of Error!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!Total Civilian Noninstitutionalized Population	Percent Margin of Error!!VETERAN STATUS!!Civilian population 18 years and over!!Civilian veterans
# DP05_0008EA	Annotation of Estimate!!SEX AND AGE!!20 to 24 years	Annotation of Estimate!!SEX AND AGE!!Total population!!15 to 19 years
# DP04_0135EA	Annotation of Estimate!!GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!Occupied units paying rent (excluding units where GRAPI cannot be computed)!!Less than 15.0 percent	Annotation of Estimate!!GROSS RENT!!Occupied units paying rent!!No rent paid
# DP05_0028EA	Annotation of Estimate!!RACE!!Total population	Annotation of Estimate!!SEX AND AGE!!Total population!!18 years and over!!Sex ratio (males per 100 females)
# DP04_0069EA	Annotation of Estimate!!HOUSE HEATING FUEL!!Occupied housing units!!Other fuel	Annotation of Estimate!!HOUSE HEATING FUEL!!Occupied housing units!!Solar energy
# DP02_0027PMA	Annotation of Percent Margin of Error!!MARITAL STATUS!!Males 15 years and over!!Separated	Annotation of Percent Margin of Error!!MARITAL STATUS!!Males 15 years and over!!Now married, except separated
# DP04_0091MA	Annotation of Margin of Error!!MORTGAGE STATUS!!Owner-occupied units!!Housing units without a mortgage	Annotation of Margin of Error!!MORTGAGE STATUS!!Owner-occupied units!!Housing units with a mortgage
# DP03_0103PEA	Annotation of Percent!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population 18 to 64 years!!In labor force	Annotation of Percent!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population 19 to 64 years!!In labor force:
# DP04_0081PEA	Annotation of Percent!!VALUE!!Owner-occupied units!!$50,000 to $99,999	Annotation of Percent!!VALUE!!Owner-occupied units!!Less than $50,000
# DP02_0151PMA	Annotation of Percent Margin of Error!!COMPUTERS AND INTERNET USE!!Total Households!!With a computer	Annotation of Percent Margin of Error!!COMPUTERS AND INTERNET USE!!Total households
# DP03_0086E	Estimate!!INCOME AND BENEFITS (IN 2014 INFLATION-ADJUSTED DOLLARS)!!Families!!Median family income (dollars)	Estimate!!INCOME AND BENEFITS (IN 2019 INFLATION-ADJUSTED DOLLARS)!!Families!!Median family income (dollars)
# DP04_0051MA	Annotation of Margin of Error!!YEAR HOUSEHOLDER MOVED INTO UNIT!!Occupied housing units!!Moved in 2000 to 2009	Annotation of Margin of Error!!YEAR HOUSEHOLDER MOVED INTO UNIT!!Occupied housing units!!Moved in 2017 or later
# DP02_0099EA	Annotation of Estimate!!YEAR OF ENTRY!!Native!!Entered before 2010	Annotation of Estimate!!YEAR OF ENTRY!!Population born outside the United States!!Native!!Entered 2010 or later
# DP04_0100M	Margin of Error!!SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units with a mortgage!!Median (dollars)	Margin of Error!!SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units with a mortgage!!$3,000 or more
# DP04_0018E	Estimate!!YEAR STRUCTURE BUILT!!Total housing units!!Built 2000 to 2009	Estimate!!YEAR STRUCTURE BUILT!!Total housing units!!Built 2010 to 2013
# DP02_0116M	Margin of Error!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Other Indo-European languages	Margin of Error!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Spanish!!Speak English less than "very well"
# DP03_0094EA	Annotation of Estimate!!INCOME AND BENEFITS (IN 2014 INFLATION-ADJUSTED DOLLARS)!!Median earnings for female full-time, year-round workers (dollars)	Annotation of Estimate!!INCOME AND BENEFITS (IN 2019 INFLATION-ADJUSTED DOLLARS)!!Median earnings for female full-time, year-round workers (dollars)
# DP03_0131PMA	Annotation of Percent Margin of Error!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!Under 18 years!!Related children under 18 years!!Related children under 5 years	Annotation of Percent Margin of Error!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All people!!Under 18 years!!Related children of the householder under 18 years!!Related children of the householder under 5 years
# DP04_0094PEA	Annotation of Percent!!SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units with a mortgage!!$300 to $499	Annotation of Percent!!SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units with a mortgage!!Less than $500
# DP04_0095PEA	Annotation of Percent!!SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units with a mortgage!!$500 to $699	Annotation of Percent!!SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units with a mortgage!!$500 to $999
# DP05_0065MA	Annotation of Margin of Error!!HISPANIC OR LATINO AND RACE!!Total population	Annotation of Margin of Error!!Race alone or in combination with one or more other races!!Total population!!Black or African American
# DP05_0010EA	Annotation of Estimate!!SEX AND AGE!!35 to 44 years	Annotation of Estimate!!SEX AND AGE!!Total population!!25 to 34 years
# DP02_0028PMA	Annotation of Percent Margin of Error!!MARITAL STATUS!!Males 15 years and over!!Widowed	Annotation of Percent Margin of Error!!MARITAL STATUS!!Males 15 years and over!!Separated
# DP04_0099PM	Percent Margin of Error!!SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units with a mortgage!!$2,000 or more	Percent Margin of Error!!SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units with a mortgage!!$2,500 to $2,999
# DP02_0064M	Margin of Error!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Bachelor's degree	Margin of Error!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Associate's degree
# DP02_0090E	Estimate!!PLACE OF BIRTH!!Total population!!Native!!Born in United States!!Different state	Estimate!!PLACE OF BIRTH!!Total population!!Native!!Born in United States!!State of residence
# DP02_0117PMA	Annotation of Percent Margin of Error!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Other Indo-European languages!!Speak English less than "very well"	Annotation of Percent Margin of Error!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Other Indo-European languages
# DP05_0021PMA	Annotation of Percent Margin of Error!!SEX AND AGE!!65 years and over	Annotation of Percent Margin of Error!!SEX AND AGE!!Total population!!18 years and over
# DP02_0084PEA	Annotation of Percent!!RESIDENCE 1 YEAR AGO!!Population 1 year and over!!Different house in the U.S.!!Different county!!Different state	Annotation of Percent!!RESIDENCE 1 YEAR AGO!!Population 1 year and over!!Different house in the U.S.!!Different county!!Same state
# DP02_0035M	Margin of Error!!MARITAL STATUS!!Females 15 years and over!!Divorced	Margin of Error!!MARITAL STATUS!!Females 15 years and over!!Widowed
# DP02_0100PE	Percent!!YEAR OF ENTRY!!Foreign born	Percent!!YEAR OF ENTRY!!Population born outside the United States!!Native!!Entered before 2010
# DP04_0064PEA	Annotation of Percent!!HOUSE HEATING FUEL!!Occupied housing units!!Electricity	Annotation of Percent!!HOUSE HEATING FUEL!!Occupied housing units!!Bottled, tank, or LP gas
# DP02_0045E	Estimate!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Years responsible for grandchildren!!Less than 1 year	Estimate!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Grandparents responsible for grandchildren
# DP02_0075MA	Annotation of Margin of Error!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!18 to 64 years!!With a disability	Annotation of Margin of Error!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!18 to 64 years
# DP02_0122PM	Percent Margin of Error!!ANCESTRY!!Total population	Percent Margin of Error!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Other languages!!Speak English less than "very well"
# DP03_0129EA	Annotation of Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!Under 18 years	Annotation of Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All people!!Under 18 years
# DP04_0062EA	Annotation of Estimate!!HOUSE HEATING FUEL!!Occupied housing units!!Utility gas	Annotation of Estimate!!HOUSE HEATING FUEL!!Occupied housing units
# DP04_0071PEA	Annotation of Percent!!SELECTED CHARACTERISTICS!!Occupied housing units	Annotation of Percent!!HOUSE HEATING FUEL!!Occupied housing units!!No fuel used
# DP05_0075E	Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Not Hispanic or Latino!!Asian alone	Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)!!Other Hispanic or Latino
# DP04_0037PMA	Annotation of Percent Margin of Error!!BEDROOMS!!Total housing units	Annotation of Percent Margin of Error!!ROOMS!!Total housing units!!Median rooms
# DP05_0035PE	Percent!!RACE!!One race!!American Indian and Alaska Native!!Cherokee tribal grouping	Percent!!RACE!!Total population!!Two or more races
# DP02_0094M	Margin of Error!!U.S. CITIZENSHIP STATUS!!Foreign-born population!!Naturalized U.S. citizen	Margin of Error!!U.S. CITIZENSHIP STATUS!!Foreign-born population
# DP02_0046M	Margin of Error!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Years responsible for grandchildren!!1 or 2 years	Margin of Error!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Years responsible for grandchildren!!Less than 1 year
# DP04_0117PEA	Annotation of Percent!!SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI)!!Housing unit without a mortgage (excluding units where SMOCAPI cannot be computed)!!10.0 to 14.9 percent	Annotation of Percent!!SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI)!!Housing unit without a mortgage (excluding units where SMOCAPI cannot be computed)
# DP02_0131PM	Percent Margin of Error!!ANCESTRY!!Total population!!German	Percent Margin of Error!!ANCESTRY!!Total population!!French Canadian
# DP03_0063MA	Annotation of Margin of Error!!INCOME AND BENEFITS (IN 2014 INFLATION-ADJUSTED DOLLARS)!!Total households!!Mean household income (dollars)	Annotation of Margin of Error!!INCOME AND BENEFITS (IN 2019 INFLATION-ADJUSTED DOLLARS)!!Total households!!Mean household income (dollars)
# DP05_0034E	Estimate!!RACE!!One race!!American Indian and Alaska Native	Estimate!!RACE!!Total population!!One race
# DP05_0059PMA	Annotation of Percent Margin of Error!!RACE!!Race alone or in combination with one or more other races!!Total population!!White	Annotation of Percent Margin of Error!!RACE!!Total population!!Two or more races!!White and Black or African American
# DP04_0088PMA	Annotation of Percent Margin of Error!!VALUE!!Owner-occupied units!!Median (dollars)	Annotation of Percent Margin of Error!!VALUE!!Owner-occupied units!!$1,000,000 or more
# DP02_0044PM	Percent Margin of Error!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Responsible for grandchildren	Percent Margin of Error!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years
# DP04_0138PEA	Annotation of Percent!!GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!Occupied units paying rent (excluding units where GRAPI cannot be computed)!!25.0 to 29.9 percent	Annotation of Percent!!GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!Occupied units paying rent (excluding units where GRAPI cannot be computed)!!15.0 to 19.9 percent
# DP02_0055M	Margin of Error!!SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)	Margin of Error!!SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten
# DP04_0042MA	Annotation of Margin of Error!!BEDROOMS!!Total housing units!!4 bedrooms	Annotation of Margin of Error!!BEDROOMS!!Total housing units!!3 bedrooms
# DP05_0081PE	Percent!!Total housing units	Percent!!HISPANIC OR LATINO AND RACE!!Total population!!Not Hispanic or Latino!!Native Hawaiian and Other Pacific Islander alone
# DP03_0112EA	Annotation of Estimate!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population 18 to 64 years!!In labor force!!Unemployed!!With health insurance coverage!!With public coverage	Annotation of Estimate!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population 19 to 64 years!!In labor force:!!Unemployed:!!With health insurance coverage!!With public coverage
# DP04_0033MA	Annotation of Margin of Error!!ROOMS!!Total housing units!!7 rooms	Annotation of Margin of Error!!ROOMS!!Total housing units!!6 rooms
# DP02_0091MA	Annotation of Margin of Error!!PLACE OF BIRTH!!Total population!!Native!!Born in Puerto Rico, U.S. Island areas, or born abroad to American parent(s)	Annotation of Margin of Error!!PLACE OF BIRTH!!Total population!!Native!!Born in United States!!Different state
# DP03_0060PEA	Annotation of Percent!!INCOME AND BENEFITS (IN 2014 INFLATION-ADJUSTED DOLLARS)!!Total households!!$150,000 to $199,999	Annotation of Percent!!INCOME AND BENEFITS (IN 2019 INFLATION-ADJUSTED DOLLARS)!!Total households!!$150,000 to $199,999
# DP05_0053MA	Annotation of Margin of Error!!RACE!!Two or more races	Annotation of Margin of Error!!RACE!!Total population!!One race!!Native Hawaiian and Other Pacific Islander!!Native Hawaiian
# DP05_0043M	Margin of Error!!RACE!!One race!!Asian!!Japanese	Margin of Error!!RACE!!Total population!!One race!!American Indian and Alaska Native!!Sioux tribal grouping
# DP02_0116E	Estimate!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Other Indo-European languages	Estimate!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Spanish!!Speak English less than "very well"
# DP04_0017MA	Annotation of Margin of Error!!YEAR STRUCTURE BUILT!!Total housing units!!Built 2010 or later	Annotation of Margin of Error!!YEAR STRUCTURE BUILT!!Total housing units!!Built 2014 or later
